# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\fact-pc\anaconda3\envs\torch38\lib\site-packages (4.2.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\fact-pc\anaconda3\envs\torch38\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\fact-pc\anaconda3\envs\torch38\lib\site-packages (from gensim) (6.0.0)
# Requirement already satisfied: Cython==0.29.28 in c:\users\fact-pc\anaconda3\envs\torch38\lib\site-packages (from gensim) (0.29.28)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\fact-pc\anaconda3\envs\torch38\lib\site-packages (from gensim) (1.21.6)

# %%
# import libraries
import pandas as pd
import plotly.express as px
import re
import nltk
import pickle
import numpy as np

# %%
import glob, os

all_files = glob.glob("../../data_lyrics/thaisongs/*.csv")

li = []

for filename in all_files:
    song_df = pd.read_csv(filename, index_col=None, header=0)
    li.append(song_df)

song_df = pd.concat(li, axis=0, ignore_index=True)

# %%
# remove !@#$%^&*()_+
lyric_in_round_brackets = sum(list(song_df['lyric'].map(lambda s: re.findall(r'\((.*?)\)',s))), [])
lyric_in_square_brackets = sum(list(song_df['lyric'].map(lambda s: re.findall(r'\[(.*?)\]',s))), [])
lyric_in_curly_brackets = sum(list(song_df['lyric'].map(lambda s: re.findall(r'\{(.*?)\}',s))), [])
dot = sum(list(song_df['lyric'].map(lambda s: re.findall('\.',s))), [])
star = sum(list(song_df['lyric'].map(lambda s: re.findall('\*',s))), [])
semi_colon = sum(list(song_df['lyric'].map(lambda s: re.findall('\;',s))), [])
colon = sum(list(song_df['lyric'].map(lambda s: re.findall('\:',s))), [])
exclam_mark = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\!",s))), [])
slash = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\/",s))), [])
slashR = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\\",s))), [])
question_mark = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\?",s))), [])
hashtag = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\#",s))), [])
percent = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\%",s))), [])
plus = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\+",s))), [])
minus = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\-",s))), [])
comma = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\,",s))), [])
sg_quote = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\'",s))), [])
db_quote = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\"",s))), [])
dollar_sign = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\$",s))), [])
ampersand = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\&",s))), [])
underscore = sum(list(song_df['lyric'].map(lambda s: re.findall(r"\_",s))), [])


song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\((.*?)\)', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\[(.*?)\]', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\{(.*?)\}', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\.', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\*', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\;', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\:', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\!", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\/", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\\', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\?", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\#", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\%", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\+", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\-", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\,", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r"\'", '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\"', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\$', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\&', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\_', '', s))
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r'\(|\)', '', s))



print('Number of round brackets: {}'.format(len(lyric_in_round_brackets)))
print('Number of square brackets: {}'.format(len(lyric_in_square_brackets)))
print('Number of curly brackets: {}'.format(len(lyric_in_curly_brackets)))
print('Number of dot: {}'.format(len(dot)))
print('Number of star: {}'.format(len(star)))
print('Number of semi colon: {}'.format(len(semi_colon)))
print('Number of colon: {}'.format(len(colon)))
print('Number of exclamation mark: {}'.format(len(exclam_mark)))
print('Number of slash: {}'.format(len(slash)))
print('Number of slashR: {}'.format(len(slashR)))
print('Number of question mark: {}'.format(len(question_mark)))
print('Number of hashtag: {}'.format(len(hashtag)))
print('Number of percent: {}'.format(len(percent)))
print('Number of plus: {}'.format(len(plus)))
print('Number of minus: {}'.format(len(minus)))
print('Number of comma: {}'.format(len(comma)))
print('Number of single quote: {}'.format(len(sg_quote)))
print('Number of double quote: {}'.format(len(db_quote)))
print('Number of dollar sign: {}'.format(len(dollar_sign)))
print('Number of ampersand: {}'.format(len(ampersand)))
print('Number of underscore: {}'.format(len(underscore)))
# Out:
# Number of round brackets: 6673
# Number of square brackets: 54
# Number of curly brackets: 0
# Number of dot: 16715
# Number of star: 391
# Number of semi colon: 46
# Number of colon: 159
# Number of exclamation mark: 416
# Number of slash: 247
# Number of slashR: 1
# Number of question mark: 305
# Number of hashtag: 29
# Number of percent: 1
# Number of plus: 22
# Number of minus: 547
# Number of comma: 1466
# Number of single quote: 4960
# Number of double quote: 18
# Number of dollar sign: 2
# Number of ampersand: 44
# Number of underscore: 226

# %%
# count number of lines
song_df['lines'] = song_df['lyric'].map(lambda t: len(re.findall(r'\n', t)))

# %%
# remove line breaks
song_df['lyric'] = song_df['lyric'].map(lambda s: re.sub(r' \n|\n', '', s))

# %%
import pythainlp
from pythainlp import word_tokenize
from pythainlp.corpus.common import thai_stopwords
from pythainlp.corpus import wordnet
from nltk.stem.porter import PorterStemmer
from nltk.corpus import words
from stop_words import get_stop_words
# from pythainlp.ulmfit import process_thai

# %%
import nltk
import json
nltk.download('words')
th_stop = tuple(thai_stopwords())
en_stop = tuple(get_stop_words('en'))
p_stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package words to C:\Users\FACT-
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def split_word(text):

    tokens = word_tokenize(text,engine='newmm')
    
    # Remove stop words ภาษาไทย และภาษาอังกฤษ
    #tokens = [i for i in tokens if not i in th_stop and not i in en_stop]
    
    # หารากศัพท์ภาษาไทย และภาษาอังกฤษ (Stemming)
    # English
    tokens = [p_stemmer.stem(i) for i in tokens]
    
    # # Thai
    # tokens_temp=[]
    # for i in tokens:
    #     w_syn = wordnet.synsets(i)
    #     if (len(w_syn)>0) and (len(w_syn[0].lemma_names('tha'))>0):
    #         tokens_temp.append(w_syn[0].lemma_names('tha')[0])
    #     else:
    #         tokens_temp.append(i)
    
    # tokens = tokens_temp
    
    # ลบตัวเลข
    tokens = [i for i in tokens if not i.isnumeric()]
    
    # ลบช่องว่าง
    tokens = [i for i in tokens if not ' ' in i]

    return tokens

# %%
song_df.shape
# Out:
# (9075, 5)

# %%
text = song_df.loc[0,'lyric']
text
# Out:
# 'Look at me now ชีวิตกูสบาย Get high อยู่ข้างใน Mansion uh\rShe wanna drink my kids เธอทำมันเหมือนเธอมี Passion uh\rทุกจังหวัดที่กูไป Pistol packing never lacking uh\rพวกแม่งยังคง Cappin and my money they keep adding up uh\rไม้กางเกงบนตัวกู Chrome heart พวกมึงยังไม่ Cool บอกให้พวกแม่งค่อยๆ Grow up ya\rกูชอบแดกลีนตอนกู Sober now its over รอเหี้ไรดิ Pour up \r\rเขาบอกคนอย่างกูมัวแต่ยุ่งเกี่ยวกับเรื่องยา ยา \rIm like haha this shit got me trauma \rก่อนจะได้กิน Steak กูเคยแดกมาม่า\rกูไม่เชื่อ Karma ตอนนี้แม่กูใส่ Prada\r\rกูไม่ค่อยว่างกูอยู่ใน Club21 \rIm hotter than the summer higher than the sun\rมึงคิดว่ามันง่ายแต่ไม่ได้ดูกูทำ\rงานกู one of one และกูทำกันวันต่อวัน\r\rกูไม่ร้องขอพระเจ้าให้ Show the way\rมีแค่กูกับพี่กูที่อยู่ในคลื่นทะเล\rใครจะ Ride the wave yeah\rYou gotta make some shake yeah\r\rLook at me now ชีวิตกูสบาย Get high อยู่ข้างใน Mansion uh\rShe wanna drink my kids เธอทำมันเหมือนเธอมี Passion uh\rทุกจังหวัดที่กูไป Pistol packing never lacking uh\rพวกแม่งยังคง Cappin and my money they keep adding up uh\rไม้กางเกงบนตัวกู Chrome heart พวกมึงยังไม่ Cool บอกให้พวกแม่งค่อยๆ Grow up ya\rกูชอบแดกลีนตอนกู Sober now its over รอเหี้ไรดิ Pour up \r\rชีวิตกูสบาย Get high อยู่ข้างใน Mansion uh\rShe wanna drink my kids เธอทำมันเหมือนเธอมี Passion uh\rทุกจังหวัดที่กูไป Pistol packing never lacking'

# %%
song_df
# Out:
#                    song_name                    href  \
# 0                     1 Of 1  /music/thailyric/23579
# 1                     2Turnt  /music/thailyric/23578
# 2                 Fu*k It Up  /music/thailyric/23565
# 3                  On My Own  /music/thailyric/23566
# 4                OnSomeShit!  /music/thailyric/23577
# ...                      ...                     ...
# 9070               โลกใบเก่า  /music/thailyric/22042
# 9071          อยากมีความหมาย  /music/thailyric/18114
# 9072  อยากมีความหมาย (Empty)  /music/thailyric/21524
# 9073          อย่าไป (Still)  /music/thailyric/19403
# 9074              อยู่ (You)  /music/thailyric/16666
#
#                                                   lyric        artist  lines
# 0     Look at me now ชีวิตกูสบาย Get high อยู่ข้างใน...         1mill     31
# 1     Ay can you turn a headphone up\rIm too turnt r...         1mill     47
# 2     I just be takin these drugs takin these drugs\...         1mill    121
# 3     I like counting cash บอกพวกแม่งไม่ต้องโอน\rมึง...         1mill     42
# 4     I get the racks I get the bag พวกกูชอบ Cash\rI...         1mill     97
# ...                                                 ...           ...    ...
# 9070  หลายๆ สิ่ง ที่อยู่ข้างใน\rทบและทวน ยังไม่เคยเข...  zweed_n_roll     29
# 9071  วันนั้นถ้าเธอบังเอิญ เดินเข้ามา\rความเหนื่อยล้...  zweed_n_roll     35
# 9072  วันนั้นถ้าเธอบังเอิญ เดินเข้ามา\rความเหนื่อยล้...  zweed_n_roll     29
# 9073  เธอไม่กล้าหรอก เธอนั้นยังรอ\rเธอนั้นดูก่อน ฉัน...  zweed_n_roll     15
# 9074  เพียง ถ้าเธอสบตา ทุกอย่างสวยงาม\rทำให้ฉันรู้สึ...  zweed_n_roll     23
#
# [9075 rows x 5 columns]

# %%
# -*- coding: utf-8 -*-
from typing import List, Tuple
import warnings

from gensim.models import KeyedVectors
from gensim.models.keyedvectors import Word2VecKeyedVectors
from numpy import ndarray, zeros
from pythainlp.corpus import get_corpus_path
from pythainlp.tokenize import THAI2FIT_TOKENIZER, word_tokenize


WV_DIM = 300  # word vector dimension

_MODEL_NAME = "thai2fit_wv"

_TK_SP = "xxspace"
_TK_EOL = "xxeol"

def get_model() -> Word2VecKeyedVectors:
    path = get_corpus_path(_MODEL_NAME)
    return KeyedVectors.load_word2vec_format(path, binary=True)


_MODEL = get_model()

def sentence_vectorizer(text: str, use_mean: bool = True) -> ndarray:
    vec = zeros((1, WV_DIM))

    #words = THAI2FIT_TOKENIZER.word_tokenize(text)
    words = split_word(text)
    print(words)
    len_words = len(words)

    if not len_words:
        return vec

    for word in words:
        if word == " ":
            word = _TK_SP
        elif word == "\n":
            word = _TK_EOL

        if word in _MODEL.index_to_key:
            vec += _MODEL.get_vector(word)

    if use_mean:
        vec /= len_words

    return vec

# %%
text = text.replace('\r\r', '\r')
text_list = text.split('\r')
text_list
# Out:
# ['Look at me now ชีวิตกูสบาย Get high อยู่ข้างใน Mansion uh',
#  'She wanna drink my kids เธอทำมันเหมือนเธอมี Passion uh',
#  'ทุกจังหวัดที่กูไป Pistol packing never lacking uh',
#  'พวกแม่งยังคง Cappin and my money they keep adding up uh',
#  'ไม้กางเกงบนตัวกู Chrome heart พวกมึงยังไม่ Cool บอกให้พวกแม่งค่อยๆ Grow up ya',
#  'กูชอบแดกลีนตอนกู Sober now its over รอเหี้ไรดิ Pour up ',
#  'เขาบอกคนอย่างกูมัวแต่ยุ่งเกี่ยวกับเรื่องยา ยา ',
#  'Im like haha this shit got me trauma ',
#  'ก่อนจะได้กิน Steak กูเคยแดกมาม่า',
#  'กูไม่เชื่อ Karma ตอนนี้แม่กูใส่ Prada',
#  'กูไม่ค่อยว่างกูอยู่ใน Club21 ',
#  'Im hotter than the summer higher than the sun',
#  'มึงคิดว่ามันง่ายแต่ไม่ได้ดูกูทำ',
#  'งานกู one of one และกูทำกันวันต่อวัน',
#  'กูไม่ร้องขอพระเจ้าให้ Show the way',
#  'มีแค่กูกับพี่กูที่อยู่ในคลื่นทะเล',
#  'ใครจะ Ride the wave yeah',
#  'You gotta make some shake yeah',
#  'Look at me now ชีวิตกูสบาย Get high อยู่ข้างใน Mansion uh',
#  'She wanna drink my kids เธอทำมันเหมือนเธอมี Passion uh',
#  'ทุกจังหวัดที่กูไป Pistol packing never lacking uh',
#  'พวกแม่งยังคง Cappin and my money they keep adding up uh',
#  'ไม้กางเกงบนตัวกู Chrome heart พวกมึงยังไม่ Cool บอกให้พวกแม่งค่อยๆ Grow up ya',
#  'กูชอบแดกลีนตอนกู Sober now its over รอเหี้ไรดิ Pour up ',
#  'ชีวิตกูสบาย Get high อยู่ข้างใน Mansion uh',
#  'She wanna drink my kids เธอทำมันเหมือนเธอมี Passion uh',
#  'ทุกจังหวัดที่กูไป Pistol packing never lacking']

# %%
X_train, X_test, y_train, y_test = train_test_split(song_df['lyric'], song_df['artist'], 
                                                                    random_state=2022, 
                                                                    test_size=0.3, 
                                                                    stratify=song_df['artist'])

# %%
song_df.head()
# Out:
#      song_name                    href  \
# 0       1 Of 1  /music/thailyric/23579
# 1       2Turnt  /music/thailyric/23578
# 2   Fu*k It Up  /music/thailyric/23565
# 3    On My Own  /music/thailyric/23566
# 4  OnSomeShit!  /music/thailyric/23577
#
#                                                lyric artist  lines
# 0  Look at me now ชีวิตกูสบาย Get high อยู่ข้างใน...  1mill     31
# 1  Ay can you turn a headphone up\rIm too turnt r...  1mill     47
# 2  I just be takin these drugs takin these drugs\...  1mill    121
# 3  I like counting cash บอกพวกแม่งไม่ต้องโอน\rมึง...  1mill     42
# 4  I get the racks I get the bag พวกกูชอบ Cash\rI...  1mill     97

# %%
new_df = song_df[['artist']]
new_df = new_df.drop_duplicates(subset=['artist'])
new_df = new_df.reset_index()[['artist']]
artist_list_64 = new_df.iloc[:64]['artist'].values.tolist()

# %%
artist_list_64
# Out:
# ['1mill',
#  '1_etc',
#  '25_hours',
#  '4eve',
#  '7_days_crazy',
#  'ab_normal',
#  'add_carabao',
#  'ae_jirakorn',
#  'ake_surachet',
#  'am_fine',
#  'anan_anwar',
#  'ann_thitima',
#  'aof_pongsak',
#  'armchair',
#  'arm_chutima',
#  'asanee_wasan',
#  'atom_chanakan',
#  'a_mob',
#  'bankk_cash',
#  'bao_wee_rsiam',
#  'basher',
#  'beau_sunita',
#  'bee_namthip',
#  'bee_perapat',
#  'bell_supol',
#  'ben_chalatit',
#  'better_weather',
#  'bie_sukrit',
#  'big_ass',
#  'billkin',
#  'bird_thongchai',
#  'blackhead',
#  'ble_patumrach',
#  'blue_shade',
#  'bnk48',
#  'bodyslam',
#  'book_supakarn',
#  'boom_boom_cash',
#  'bowkylion',
#  'bowling_manida',
#  'boyd_kosiyabong',
#  'boy_peacemaker',
#  'boy_pisanu',
#  'boy_trai_bhumiratna',
#  'bright_vachirawit',
#  'briohny',
#  'buachompoo_ford',
#  'buddha_bless',
#  'budokan',
#  'burin_boonvisut',
#  'b_ble_300',
#  'calories_blah_blah',
#  'carabao',
#  'cd_guntee',
#  'chart_suchart',
#  'chilling_Sunday',
#  'chin_chinawut',
#  'christina_aguilar',
#  'cocktail',
#  'crescendo',
#  'd2b',
#  'daboyway',
#  'dan_beam',
#  'dan_worrawech']

# %%
artist_dict_64 = {}

for idx, artist in enumerate(artist_list_64):
    artist_dict_64[artist] = idx

# %%
artist_dict_64
# Out:
# {'1mill': 0,
#  '1_etc': 1,
#  '25_hours': 2,
#  '4eve': 3,
#  '7_days_crazy': 4,
#  'ab_normal': 5,
#  'add_carabao': 6,
#  'ae_jirakorn': 7,
#  'ake_surachet': 8,
#  'am_fine': 9,
#  'anan_anwar': 10,
#  'ann_thitima': 11,
#  'aof_pongsak': 12,
#  'armchair': 13,
#  'arm_chutima': 14,
#  'asanee_wasan': 15,
#  'atom_chanakan': 16,
#  'a_mob': 17,
#  'bankk_cash': 18,
#  'bao_wee_rsiam': 19,
#  'basher': 20,
#  'beau_sunita': 21,
#  'bee_namthip': 22,
#  'bee_perapat': 23,
#  'bell_supol': 24,
#  'ben_chalatit': 25,
#  'better_weather': 26,
#  'bie_sukrit': 27,
#  'big_ass': 28,
#  'billkin': 29,
#  'bird_thongchai': 30,
#  'blackhead': 31,
#  'ble_patumrach': 32,
#  'blue_shade': 33,
#  'bnk48': 34,
#  'bodyslam': 35,
#  'book_supakarn': 36,
#  'boom_boom_cash': 37,
#  'bowkylion': 38,
#  'bowling_manida': 39,
#  'boyd_kosiyabong': 40,
#  'boy_peacemaker': 41,
#  'boy_pisanu': 42,
#  'boy_trai_bhumiratna': 43,
#  'bright_vachirawit': 44,
#  'briohny': 45,
#  'buachompoo_ford': 46,
#  'buddha_bless': 47,
#  'budokan': 48,
#  'burin_boonvisut': 49,
#  'b_ble_300': 50,
#  'calories_blah_blah': 51,
#  'carabao': 52,
#  'cd_guntee': 53,
#  'chart_suchart': 54,
#  'chilling_Sunday': 55,
#  'chin_chinawut': 56,
#  'christina_aguilar': 57,
#  'cocktail': 58,
#  'crescendo': 59,
#  'd2b': 60,
#  'daboyway': 61,
#  'dan_beam': 62,
#  'dan_worrawech': 63}

# %%
song_df_64 = song_df[song_df['artist'].isin(artist_list_64)]

# %%
song_df_64['artist_id'] = song_df_64['artist'].replace(artist_dict_64)
# Out:
# C:\Users\FACT-PC\AppData\Local\Temp\ipykernel_18112\4186461608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df_64['artist_id'] = song_df_64['artist'].replace(artist_dict_64)

# %%
song_df_64
# Out:
#               song_name                    href  \
# 0                1 Of 1  /music/thailyric/23579
# 1                2Turnt  /music/thailyric/23578
# 2            Fu*k It Up  /music/thailyric/23565
# 3             On My Own  /music/thailyric/23566
# 4           OnSomeShit!  /music/thailyric/23577
# ...                 ...                     ...
# 1831           ฟ้าสีเทา   /music/thailyric/9393
# 1832  ไม่มีใครเหมือนเธอ   /music/thailyric/8435
# 1833            รักหลับ  /music/thailyric/17045
# 1834    เรื่องเล่าเหงาๆ   /music/thailyric/9787
# 1835       สภาวะทิ้งตัว   /music/thailyric/8642
#
#                                                   lyric         artist  lines  \
# 0     Look at me now ชีวิตกูสบาย Get high อยู่ข้างใน...          1mill     31
# 1     Ay can you turn a headphone up\rIm too turnt r...          1mill     47
# 2     I just be takin these drugs takin these drugs\...          1mill    121
# 3     I like counting cash บอกพวกแม่งไม่ต้องโอน\rมึง...          1mill     42
# 4     I get the racks I get the bag พวกกูชอบ Cash\rI...          1mill     97
# ...                                                 ...            ...    ...
# 1831  ในช่วงเวลาที่ท้องฟ้า\rเริ่มจะเปลี่ยนกลายเป็นสี...  dan_worrawech     55
# 1832  เคยฝากใจที่ใคร ก็เหมือนไม่เคยมั่นใจได้เลยสักที...  dan_worrawech     33
# 1833  เธอกอดเกี่ยวฉันไว้ จนร่างกายเราใกล้กัน\rยื่นหน...  dan_worrawech     45
# 1834  ในร้านเล็กๆ มีคนเหงาๆ\rดื่มชาตอนเช้าฟังเพลงเศร...  dan_worrawech     51
# 1835  ในเมืองเล็กๆ ที่มีผู้คนอยู่มากมาย\rจะมีบ้างไหม...  dan_worrawech     59
#
#       artist_id
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1831         63
# 1832         63
# 1833         63
# 1834         63
# 1835         63
#
# [1836 rows x 6 columns]

# %% [markdown]
# ### Train 64 artists

# %%
json_train = []

for i in range(song_df_64.shape[0]):
    text = song_df_64.iloc[i].lyric.replace('\r\r', '\r')
    text_list = text.split('\r')
    text_dict = {'src':[], 'songId':0, 'tgt':0}
    for t in text_list:
        text_dict['src'].append((split_word(t)))
    text_dict['songId'] = i
    text_dict['tgt'] = int(song_df_64.iloc[i].artist_id)
    json_train.append(text_dict)

# %%
with open('../newmodel/js_data/thaisum.train64.0.json', 'w', encoding='utf-8') as f:
    json.dump(json_train, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Train

# %%
json_file = []

for i in range(100):
    text = X_train.iloc[i].replace('\r\r', '\r')
    text_list = text.split('\r')
    text_dict = {'src':[], 'song_id':0, 'tgt':''}
    for t in text_list:
        text_dict['src'].append((split_word(t)))
    text_dict['song_id'] = i
    text_dict['tgt'] = song_df.loc[i,'artist']
    json_file.append(text_dict)
json_file
# Out:
# [{'src': [['look',
#     'at',
#     'me',
#     'now',
#     'ชีวิต',
#     'กู',
#     'สบาย',
#     'get',
#     'high',
#     'อยู่',
#     'ข้างใน',
#     'mansion',
#     'uh'],
#    ['she',
#     'wanna',
#     'drink',
#     'my',
#     'kid',
#     'เธอ',
#     'ทำ',
#     'มัน',
#     'เหมือน',
#     'เธอ',
#     'มี',
#     'passion',
#     'uh'],
#    ['ทุก',
#     'จังหวัด',
#     'ที่',
#     'กู',
#     'ไป',
#     'pistol',
#     'pack',
#     'never',
#     'lack',
#     'uh'],
#    ['พวก',
#     'แม่',
#     'ง',
#     'ยังคง',
#     'cappin',
#     'and',
#     'my',
#     'money',
#     'they',
#     'keep',
#     'ad',
#     'up',
#     'uh'],
#    ['ไม้',
#     'กางเกง',
#     'บน',
#     'ตัว',
#     'กู',
#     'chrome',
#     'heart',
#     'พวก',
#     'มึง',
#     'ยัง',
#     'ไม่',
#     'cool',
#     'บอก',
#     'ให้',
#     'พวก',
#     'แม่',
#     'ง',
#     'ค่อยๆ',
#     'grow',
#     'up',
#     'ya'],
#    ['กู',
#     'ชอบ',
#     'แด',
#     'กลี',
#     'น',
#     'ตอน',
#     'กู',
#     'sober',
#     'now',
#     'it',
#     'over',
#     'รอ',
#     'เห',
#     'ี้',
#     'ไร',
#     'ดิ',
#     'pour',
#     'up'],
#    ['เขา',
#     'บอก',
#     'คน',
#     'อย่าง',
#     'กู',
#     'มัวแต่',
#     'ยุ่ง',
#     'เกี่ยวกับ',
#     'เรื่อง',
#     'ยา',
#     'ยา'],
#    ['im', 'like', 'haha', 'thi', 'shit', 'got', 'me', 'trauma'],
#    ['ก่อน', 'จะ', 'ได้', 'กิน', 'steak', 'กู', 'เคย', 'แดก', 'มาม่า'],
#    ['กู', 'ไม่', 'เชื่อ', 'karma', 'ตอนนี้', 'แม่', 'กู', 'ใส่', 'prada'],
#    ['กู', 'ไม่ค่อย', 'ว่าง', 'กู', 'อยู่', 'ใน', 'club'],
#    ['im', 'hotter', 'than', 'the', 'summer', 'higher', 'than', 'the', 'sun'],
#    ['มึง', 'คิด', 'ว่า', 'มัน', 'ง่าย', 'แต่', 'ไม่', 'ได้', 'ดู', 'กู', 'ทำ'],
#    ['งาน',
#     'กู',
#     'one',
#     'of',
#     'one',
#     'และ',
#     'กู',
#     'ทำ',
#     'กัน',
#     'วัน',
#     'ต่อ',
#     'วัน'],
#    ['กู', 'ไม่', 'ร้องขอ', 'พระเจ้า', 'ให้', 'show', 'the', 'way'],
#    ['มี', 'แค่', 'กู', 'กับ', 'พี่', 'กู', 'ที่อยู่', 'ใน', 'คลื่น', 'ทะเล'],
#    ['ใคร', 'จะ', 'ride', 'the', 'wave', 'yeah'],
#    ['you', 'gotta', 'make', 'some', 'shake', 'yeah'],
#    ['look',
#     'at',
#     'me',
#     'now',
#     'ชีวิต',
#     'กู',
#     'สบาย',
#     'get',
#     'high',
#     'อยู่',
#     'ข้างใน',
#     'mansion',
#     'uh'],
#    ['she',
#     'wanna',
#     'drink',
#     'my',
#     'kid',
#     'เธอ',
#     'ทำ',
#     'มัน',
#     'เหมือน',
#     'เธอ',
#     'มี',
#     'passion',
#     'uh'],
#    ['ทุก',
#     'จังหวัด',
#     'ที่',
#     'กู',
#     'ไป',
#     'pistol',
#     'pack',
#     'never',
#     'lack',
#     'uh'],
#    ['พวก',
#     'แม่',
#     'ง',
#     'ยังคง',
#     'cappin',
#     'and',
#     'my',
#     'money',
#     'they',
#     'keep',
#     'ad',
#     'up',
#     'uh'],
#    ['ไม้',
#     'กางเกง',
#     'บน',
#     'ตัว',
#     'กู',
#     'chrome',
#     'heart',
#     'พวก',
#     'มึง',
#     'ยัง',
#     'ไม่',
#     'cool',
#     'บอก',
#     'ให้',
#     'พวก',
#     'แม่',
#     'ง',
#     'ค่อยๆ',
#     'grow',
#     'up',
#     'ya'],
#    ['กู',
#     'ชอบ',
#     'แด',
#     'กลี',
#     'น',
#     'ตอน',
#     'กู',
#     'sober',
#     'now',
#     'it',
#     'over',
#     'รอ',
#     'เห',
#     'ี้',
#     'ไร',
#     'ดิ',
#     'pour',
#     'up'],
#    ['ชีวิต', 'กู', 'สบาย', 'get', 'high', 'อยู่', 'ข้างใน', 'mansion', 'uh'],
#    ['she',
#     'wanna',
#     'drink',
#     'my',
#     'kid',
#     'เธอ',
#     'ทำ',
#     'มัน',
#     'เหมือน',
#     'เธอ',
#     'มี',
#     'passion',
#     'uh'],
#    ['ทุก', 'จังหวัด', 'ที่', 'กู', 'ไป', 'pistol', 'pack', 'never', 'lack']],
#   'song_id': 0,
#   'tgt': '1mill'},
#  {'src': [['ay', 'can', 'you', 'turn', 'a', 'headphon', 'up'],
#    ['im', 'too', 'turnt', 'right', 'now'],
#    ['i', 'swear', 'the', 'god', 'im', 'so', 'geek', 'right', 'now'],
#    ['yeah'],
#    ['i', 'keep', 'me', 'a', 'glock', 'กู', 'วาง', 'ไว้', 'บน', 'เบาะ'],
#    ['เธอ', 'บอก', 'กับ', 'กู', 'ว่า', 'ให้', 'drop', 'the', 'top'],
#    ['กู',
#     'บอก',
#     'กับ',
#     'เธอ',
#     'i',
#     'said',
#     'fuck',
#     'the',
#     'law',
#     'the',
#     'cop'],
#    ['i',
#     'told',
#     'her',
#     'to',
#     'shut',
#     'up',
#     'and',
#     'come',
#     'give',
#     'me',
#     'top'],
#    ['ima', 'pour', 'tri', 'on', 'the', 'top', 'of', 'the', 'wock'],
#    ['ทุก', 'บีท', 'ที่', 'กู', 'ได้ที่', 'กู', 'ทำ', 'คือ', 'ต้อง', 'walk'],
#    ['บอก', 'คน', 'ที่', 'เกลียด', 'ให้', 'พวก', 'แม่', 'งอม', 'กระดอ'],
#    ['อย่า',
#     'มา',
#     'ทัก',
#     'ตอน',
#     'กู',
#     'turnt',
#     'เพราะ',
#     'มัน',
#     'ไม่',
#     'เหมือน',
#     'ใน',
#     'จอ'],
#    ['use',
#     'to',
#     'pop',
#     'me',
#     'a',
#     'bean',
#     'and',
#     'i',
#     'go',
#     'to',
#     'the',
#     'parti'],
#    ['และ', 'มึง', 'ก็', 'คง', 'รู้', 'i', 'dont', 'fuck', 'with', 'bacardi'],
#    ['นี้', 'คือ', 'hellcat', 'ไม่', 'ใช่', 'scat', 'แรง', 'กว่า', 'rari'],
#    ['กลับมา', 'โรงแรม', 'แฟน', 'มึง', 'ขี่', 'กู', 'เหมือน', 'harley'],
#    ['เธอ', 'มี', 'surgeri', 'หน้าตา', 'เธอ', 'เหมือน', 'barbi'],
#    ['เธอ', 'อยาก', 'เป็น', 'kim', 'k', 'nicki', 'หรือ', 'cardi'],
#    ['เธอ', 'อยาก', 'กิน', 'ชาย', 'สี่', 'หรือ', 'benihibachi'],
#    ['ima',
#     'bring',
#     'her',
#     'to',
#     'parti',
#     'and',
#     'feed',
#     'her',
#     'some',
#     'molli'],
#    ['yea', 'you', 'flop'],
#    ['ผู้คน', 'พา', 'กัน', 'ภาวนา', 'อยาก', 'ให้', 'กู', 'flop', 'no'],
#    ['im',
#     'not',
#     'เชือก',
#     'วิเศษ',
#     'พา',
#     'กู',
#     'ห',
#     'นะ',
#     'climb',
#     'to',
#     'the',
#     'top'],
#    ['yea',
#     'you',
#     'a',
#     'cop',
#     'แต่',
#     'มึง',
#     'จับ',
#     'กู',
#     'ไม่',
#     'ได้',
#     'you',
#     'a',
#     'dumbass',
#     'cop',
#     'boy'],
#    ['you',
#     'a',
#     'opp',
#     'และ',
#     'ที่',
#     'พวก',
#     'มึง',
#     'เกลียด',
#     'กู',
#     'เพราะว่า',
#     'เพลง',
#     'กู',
#     'น่ะ',
#     'pop'],
#    ['ผู้คน',
#     'ต่าง',
#     'เรียก',
#     'กู',
#     'ว่า',
#     'trap',
#     'star',
#     'ไม่',
#     'มี',
#     'trap',
#     'king'],
#    ['อย่า', 'มา', 'act', 'hard'],
#    ['ไป',
#     'ที่',
#     'เม',
#     'กา',
#     'กู',
#     'นั่ง',
#     'trackhawk',
#     'และ',
#     'มึง',
#     'ไม่ต้อง',
#     'มา',
#     'เสือก',
#     'อยู่',
#     'ใน',
#     'trap',
#     'spot'],
#    ['i', 'think', 'he', 'prolli', 'on', 'some', 'crack', 'amp', 'rock'],
#    ['บอก', 'กับ', 'พวก', 'แม่', 'ง', 'ให้', 'แม่', 'ง', 'back', 'up'],
#    ['กู', 'รัก', 'ที่จะ', 'trap', 'อยู่', 'ใน', 'bangkok'],
#    ['และ', 'ตอนนี้', 'ให้', 'มา', 'ดู', 'กู', 'มี', 'rack', 'up'],
#    ['now', 'im', 'sack', 'up', 'ให้', 'มา', 'ดู', 'ตอน', 'กู', 'shoppin'],
#    ['เขา', 'บอ', 'กว่า', 'กู', 'หาย', 'but', 'im', 'still', 'droppin'],
#    ['ให้', 'มา', 'ดู', 'รถ', 'ที่', 'กู', 'ซื้อ', 'กู', 'จะ', 'hop', 'in'],
#    ['กู',
#     'พูด',
#     'แล้ว',
#     'กู',
#     'ทำ',
#     'โธ่',
#     'ไอ่',
#     'น้อง',
#     'มึง',
#     'ยัง',
#     'talkin'],
#    ['เด็ก', 'ตามมา', 'ดู', 'รอยเท้า', 'กู', 'when', 'im', 'walkin'],
#    ['มือ',
#     'กู',
#     'จับ',
#     'ไว้',
#     'ที่',
#     'ปืน',
#     'ตอนที่',
#     'กู',
#     'นั้น',
#     'walk',
#     'in'],
#    ['when', 'i', 'walk', 'in', 'you', 'can', 'see', 'i', 'wa', 'flossin'],
#    ['และ', 'กู', 'ต้อง', 'ไป', 'ต่อ', 'อีก', 'ที่', 'my', 'plug', 'callin'],
#    ['i', 'wa', 'just', 'fuck', 'around', 'rappin', 'thi', 'shit'],
#    ['fuck', 'it', 'you', 'alreadi', 'know'],
#    ['slatt']],
#   'song_id': 1,
#   'tgt': '1mill'}]

# %% [markdown]
# ### Test

# %%
with open('song.json', 'w', encoding='utf-8') as f:
    json.dump(json_file, f, ensure_ascii=False, indent=4)
