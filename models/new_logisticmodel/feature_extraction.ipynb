# %% [markdown]
# ### Import Library

# %%
# import libraries
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import random
from scipy.sparse import csr_matrix, vstack
# from textblob import TextBlob
# from langdetect import detect_langs
import pickle

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Import the clean data

# %%
song_df = pd.read_pickle('../../data_lyrics/pd/clean_th_songs_35.pkl')

# %%
# song_df = song_df.astype({"artist": 'category', "song_name": 'category', "href": 'string', "lyric": 'string', 'lines': 'int64', 'words': object, 'n_words': 'int64', 'words_str': 'string', 'artists': object, 'duplicates': 'int64', 'n_artists': 'int64'})
# song_df.dtypes

# %%
song_df.head()
# Out:
#            artist    song_name                    href  \
# 0  bird_thongchai         Okay  /music/thailyric/13588
# 1  bird_thongchai  กว่าจักรวาล  /music/thailyric/13978
# 2  bird_thongchai        กำแพง  /music/thailyric/14111
# 3  bird_thongchai  ชีวิตเดี่ยว  /music/thailyric/13796
# 4  bird_thongchai    ผู้ต้องหา  /music/thailyric/13825
#
#                                                lyric  lines  \
# 0  ไม่ว่าจะเป็นยังไง Baby its Okay\rไม่ว่าจะเกิดอ...     57
# 1  จะยอมนั่งจรวด ไปตรวจดาวอังคาร\rหากว่าที่แห่งนั...     31
# 2  ถ้าเคยพบเจอ กำแพงที่ดูทั้งใหญ่และสูงชัน\rเธอรู...     39
# 3  อยู่ตรงนี้แค่เพียงลำพัง\rกับความเหงาที่เป็นดั่...     50
# 4  แค่ตัวคนเดียวไม่ตายล่ะมั้ง\rถามใจกี่ครั้งก็ยัง...     65
#
#                                                words  n_words  \
# 0  [ไม่, ว่า, จะ, เป็น, ยังไง, babi, it, okay, ไม...      343
# 1  [จะ, ยอม, นั่ง, จรวด, ไป, ตรวจ, ดาวอังคาร, หาก...      239
# 2  [ถ้า, เคย, พบ, เจอ, กำแพง, ที่, ดู, ทั้ง, ใหญ่...      316
# 3  [อยู่, ตรงนี้, แค่, เพียงลำพัง, กับ, ความเหงา,...      250
# 4  [แค่, ตัว, คนเดียว, ไม่, ตาย, ล่ะ, มั้ง, ถาม, ...      416
#
#                                            words_str           artists  \
# 0  ไม่ ว่า จะ เป็น ยังไง babi it okay ไม่ ว่า จะ ...  {bird_thongchai}
# 1  จะ ยอม นั่ง จรวด ไป ตรวจ ดาวอังคาร หาก ว่าที่ ...  {bird_thongchai}
# 2  ถ้า เคย พบ เจอ กำแพง ที่ ดู ทั้ง ใหญ่ และ สูงช...  {bird_thongchai}
# 3  อยู่ ตรงนี้ แค่ เพียงลำพัง กับ ความเหงา ที่ เป...  {bird_thongchai}
# 4  แค่ ตัว คนเดียว ไม่ ตาย ล่ะ มั้ง ถาม ใจ กี่ คร...  {bird_thongchai}
#
#    duplicates  n_artists
# 0           0          1
# 1           0          1
# 2           0          1
# 3           0          1
# 4           0          1

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Number of words

# %%
n_artist = len(song_df['artist'].unique())
random.seed(0)

artist_select = random.choices(song_df['artist'].unique(), k=n_artist)

song_filter_df = song_df.loc[song_df['artist'].isin(artist_select)]
print('Total number of songs: {}'.format(len(song_filter_df)))
song_filter_df.groupby('artist')[['song_name']].count().reset_index().rename(columns={'song_name':'n_songs'})
# Out:
# Total number of songs: 1295
#                artist  n_songs
# 0            25_hours       35
# 1         add_carabao       35
# 2         ann_thitima       35
# 3             big_ass       35
# 4      bird_thongchai       35
# 5               bnk48       35
# 6            bodyslam       35
# 7             carabao       35
# 8            cocktail       35
# 9       da_endorphine       35
# 10      dunk_phunkorn       35
# 11     film_rattapoom       35
# 12       keng_tachaya       35
# 13              klear       35
# 14           labanoon       35
# 15          lomosonic       35
# 16       maew_jirasak       35
# 17            mc_king       35
# 18           new_jiew       35
# 19   nicole_theriault       35
# 20          nut_meria       35
# 21     pai_pongsatorn       35
# 22            palapol       35
# 23              palmy       35
# 24   panadda_ruangwut       35
# 25            paradox       35
# 26     parn_thanaporn       35
# 27      petch_saharat       35
# 28         pu_pongsit       35
# 29             scrubb       35
# 30           sek_loso       35
# 31        silly_fools       35
# 32       slot_machine       35
# 33  takkatan_chollada       35
# 34            urboytj       35
# 35                vkl       35
# 36      wan_thanakrit       35

# %%
fig = px.box(song_filter_df, x='artist', y='n_words', title='Word count per song by artist')
fig.show()

# %%
song_filter_df
# Out:
#               artist                        song_name                    href  \
# 0     bird_thongchai                             Okay  /music/thailyric/13588
# 1     bird_thongchai                      กว่าจักรวาล  /music/thailyric/13978
# 2     bird_thongchai                            กำแพง  /music/thailyric/14111
# 3     bird_thongchai                      ชีวิตเดี่ยว  /music/thailyric/13796
# 4     bird_thongchai                        ผู้ต้องหา  /music/thailyric/13825
# ...              ...                              ...                     ...
# 2200        sek_loso  อย่ายอมแพ้ (โดยที่ยังไม่ต่อสู้)   /music/thailyric/5703
# 2201        sek_loso                ก้อนเนื้อข้างซ้าย   /music/thailyric/5684
# 2202        sek_loso                     ขาร็อคขาเลาะ  /music/thailyric/13264
# 2203        sek_loso              ใจสลายที่ราชประสงค์  /music/thailyric/10711
# 2204        sek_loso             ฉันเกิดในรัชกาลที่ 9  /music/thailyric/11844
#
#                                                   lyric  lines  \
# 0     ไม่ว่าจะเป็นยังไง Baby its Okay\rไม่ว่าจะเกิดอ...     57
# 1     จะยอมนั่งจรวด ไปตรวจดาวอังคาร\rหากว่าที่แห่งนั...     31
# 2     ถ้าเคยพบเจอ กำแพงที่ดูทั้งใหญ่และสูงชัน\rเธอรู...     39
# 3     อยู่ตรงนี้แค่เพียงลำพัง\rกับความเหงาที่เป็นดั่...     50
# 4     แค่ตัวคนเดียวไม่ตายล่ะมั้ง\rถามใจกี่ครั้งก็ยัง...     65
# ...                                                 ...    ...
# 2200  เส้นทางนั้นฉันเคยเดินผ่านมา\rเส้นทางโน้นฉันก็เ...     31
# 2201  ฉันเหงาเหลือเกิน\rตั้งแต่วันที่เธอจากฉันไป\rเห...     28
# 2202  สาวเอ้ยบ้านน้องอยู่ไส\rมันเป็นจั๋งได๋ คือมาน่า...     42
# 2203  เหมือนฟ้าถล่ม ลงกลางหัวใจ\rเมื่อเธอจากไป ไม่มี...     37
# 2204  ฉันเกิดในรัชกาลที่เก้า\rฉันเกิดบนพื้นแผ่นดินไท...     47
#
#                                                   words  n_words  \
# 0     [ไม่, ว่า, จะ, เป็น, ยังไง, babi, it, okay, ไม...      343
# 1     [จะ, ยอม, นั่ง, จรวด, ไป, ตรวจ, ดาวอังคาร, หาก...      239
# 2     [ถ้า, เคย, พบ, เจอ, กำแพง, ที่, ดู, ทั้ง, ใหญ่...      316
# 3     [อยู่, ตรงนี้, แค่, เพียงลำพัง, กับ, ความเหงา,...      250
# 4     [แค่, ตัว, คนเดียว, ไม่, ตาย, ล่ะ, มั้ง, ถาม, ...      416
# ...                                                 ...      ...
# 2200  [เส้นทาง, นั้น, ฉัน, เคย, เดินผ่าน, มา, เส้น, ...      166
# 2201  [ฉัน, เหงา, เหลือเกิน, ตั้งแต่, วันที่, เธอ, จ...      170
# 2202  [สาว, เอ้ย, บ้าน, น้อง, อยู่, ไส, มัน, เป็น, จ...      271
# 2203  [เหมือน, ฟ้า, ถล่ม, ลง, กลาง, หัวใจ, เมื่อ, เธ...      223
# 2204  [ฉัน, เกิด, ใน, รัชกาล, ที่, เก้า, ฉัน, เกิด, ...      233
#
#                                               words_str           artists  \
# 0     ไม่ ว่า จะ เป็น ยังไง babi it okay ไม่ ว่า จะ ...  {bird_thongchai}
# 1     จะ ยอม นั่ง จรวด ไป ตรวจ ดาวอังคาร หาก ว่าที่ ...  {bird_thongchai}
# 2     ถ้า เคย พบ เจอ กำแพง ที่ ดู ทั้ง ใหญ่ และ สูงช...  {bird_thongchai}
# 3     อยู่ ตรงนี้ แค่ เพียงลำพัง กับ ความเหงา ที่ เป...  {bird_thongchai}
# 4     แค่ ตัว คนเดียว ไม่ ตาย ล่ะ มั้ง ถาม ใจ กี่ คร...  {bird_thongchai}
# ...                                                 ...               ...
# 2200  เส้นทาง นั้น ฉัน เคย เดินผ่าน มา เส้น ทางโน้น ...        {sek_loso}
# 2201  ฉัน เหงา เหลือเกิน ตั้งแต่ วันที่ เธอ จาก ฉัน ...        {sek_loso}
# 2202  สาว เอ้ย บ้าน น้อง อยู่ ไส มัน เป็น จั๋ง ได๋ ค...        {sek_loso}
# 2203  เหมือน ฟ้า ถล่ม ลง กลาง หัวใจ เมื่อ เธอ จากไป ...        {sek_loso}
# 2204  ฉัน เกิด ใน รัชกาล ที่ เก้า ฉัน เกิด บน พื้น แ...        {sek_loso}
#
#       duplicates  n_artists
# 0              0          1
# 1              0          1
# 2              0          1
# 3              0          1
# 4              0          1
# ...          ...        ...
# 2200           0          1
# 2201           0          1
# 2202           0          1
# 2203           0          1
# 2204           0          1
#
# [1295 rows x 11 columns]

# %% [markdown]
# ### Repeated

# %%
# number of unique stems
song_df['n_unique_words'] = song_df['words'].map(lambda lst: len(set(lst)))

# ratio of unique stems
song_df['unique_words_ratio'] = song_df['n_unique_words'] / song_df['n_words']

# attach column to selected artists
song_filter_df = song_filter_df.join(song_df['unique_words_ratio'])

# %%
fig = px.box(song_filter_df, x='artist', y='unique_words_ratio', title='Ratio of unique words to all words')
fig.show()

# %% [markdown]
# ### Words per line

# %%
# calculate number of words per line
song_df['words_per_line'] = song_df['n_words'] / song_df['lines'].astype(float)

song_filter_df = song_filter_df.join(song_df['words_per_line'])

# %%
fig = px.box(song_filter_df, x='artist', y='words_per_line', title='Words per line')
fig.show()

# %% [markdown]
# ## TFIDF

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
# initialise count vectorizer
cv = CountVectorizer(analyzer=lambda x:x.split())

word_count_vector = cv.fit_transform(song_df['words_str'])

# compute idf
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
# print idf values
tfidf_df = pd.DataFrame({'word': cv.get_feature_names(), 'weight': tfidf_transformer.idf_})
 
# get lowest weights
tfidf_df.sort_values('weight').head()
# Out:
# c:\Users\FACT-PC\anaconda3\envs\torch38\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#       word    weight
# 14885  ไม่  1.100365
# 6965   ที่  1.171934
# 5263    จะ  1.187422
# 14855   ไป  1.192277
# 14734  ให้  1.210286

# %%
cv.get_feature_names()
# Out:
# c:\Users\FACT-PC\anaconda3\envs\torch38\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
# ['[',
#  'a',
#  'about',
#  'aboutask',
#  'aboutthat',
#  'abov',
#  'abovefre',
#  'abovefrozen',
#  'abovehigh',
#  'aboveriseris',
#  'aboveso',
#  'aboveth',
#  'abovethey',
#  'aboveyour',
#  'absolut',
#  'accent',
#  'accenteast',
#  'accessori',
#  'ace',
#  'achievedrap',
#  'across',
#  'act',
#  'actionsguess',
#  'ad',
#  'adapt',
#  'addi',
#  'addict',
#  'address',
#  'adventur',
#  'aey',
#  'afraid',
#  'afraidy',
#  'after',
#  'again',
#  'againbecaus',
#  'againbut',
#  'againgood',
#  'againlov',
#  'agent',
#  'agreether',
#  'ah',
#  'aha',
#  'ahand',
#  'ahead',
#  'ahgiv',
#  'ahh',
#  'ahheat',
#  'ahsh',
#  'ahw',
#  'ai',
#  'aim',
#  'aint',
#  'air',
#  'airlin',
#  'airto',
#  'aitakatta',
#  'aitakattaaitakatta',
#  'aixd',
#  'ak',
#  'album',
#  'albumnow',
#  'alcohol',
#  'alert',
#  'alexanderruth',
#  'aliveheaven',
#  'all',
#  'alla',
#  'alley',
#  'alli',
#  'allmi',
#  'allowin',
#  'allth',
#  'allyou',
#  'alon',
#  'aloneand',
#  'alonebabi',
#  'alonei',
#  'alonejust',
#  'alonenow',
#  'alonewhen',
#  'along',
#  'alongand',
#  'alreadi',
#  'alreadyso',
#  'alright',
#  'alrightar',
#  'alrighteverybodyjabaja',
#  'alrightjabaja',
#  'alrightjust',
#  'alrightlik',
#  'alrightrap',
#  'alrightwer',
#  'alskar',
#  'alway',
#  'alwaysand',
#  'alwaysbabi',
#  'am',
#  'amcuz',
#  'america',
#  'amnoth',
#  'among',
#  'amot',
#  'amp',
#  'amsexi',
#  'amyou',
#  'an',
#  'anata',
#  'and',
#  'andi',
#  'andthat',
#  'andwhen',
#  'ang',
#  'angel',
#  'angelgod',
#  'angelyour',
#  'ani',
#  'animalit',
#  'animalswho',
#  'ann',
#  'anoth',
#  'answer',
#  'anybodi',
#  'anymor',
#  'anyon',
#  'anyth',
#  'anythinga',
#  'anythingi',
#  'anytim',
#  'anyway',
#  'anywayi',
#  'aouuubr',
#  'ap',
#  'apart',
#  'apartand',
#  'apartif',
#  'apartitl',
#  'apartyour',
#  'app',
#  'appealin',
#  'appear',
#  'appearjust',
#  'applicationil',
#  'appreci',
#  'approach',
#  'aquaman',
#  'archer',
#  'are',
#  'arebabi',
#  'arehow',
#  'arei',
#  'arelost',
#  'arew',
#  'arey',
#  'ark',
#  'armour',
#  'armsif',
#  'armybattl',
#  'around',
#  'aroundbut',
#  'aroundfrom',
#  'aroundi',
#  'aroundlik',
#  'aroundmi',
#  'aroundup',
#  'aroundy',
#  'art',
#  'artist',
#  'as',
#  'asian',
#  'ask',
#  'ass',
#  'asshmmmim',
#  'assshak',
#  'at',
#  'atguess',
#  'atimma',
#  'atstil',
#  'attitud',
#  'attractionbut',
#  'auckland',
#  'audi',
#  'audidamn',
#  'auto',
#  'autotun',
#  'aw',
#  'awak',
#  'award',
#  'away',
#  'awayand',
#  'awaybut',
#  'awaydont',
#  'awayi',
#  'awayim',
#  'awaymi',
#  'awaynev',
#  'awayno',
#  'awaystealin',
#  'awaythat',
#  'awaytri',
#  'awaywer',
#  'awaywhen',
#  'awayy',
#  'awayyour',
#  'awayyouv',
#  'ay',
#  'aye',
#  'ayeoh',
#  'b',
#  'babe',
#  'babelet',
#  'babether',
#  'babi',
#  'babyand',
#  'babybabi',
#  'babybr',
#  'babycom',
#  'babycuz',
#  'babyhey',
#  'babyheysexi',
#  'babyhoney',
#  'babyi',
#  'babyiil',
#  'babyil',
#  'babyim',
#  'babylet',
#  'babylil',
#  'babylook',
#  'babyoh',
#  'babyooh',
#  'babytri',
#  'babyw',
#  'babywhat',
#  'babyy',
#  'babyyeah',
#  'babyyour',
#  'back',
#  'backand',
#  'backbut',
#  'backcaus',
#  'backfeel',
#  'backgonna',
#  'backgot',
#  'backonli',
#  'backwardsupsid',
#  'bad',
#  'badi',
#  'bae',
#  'baeyal',
#  'bag',
#  'balen',
#  'ball',
#  'bambam',
#  'banabananayeah',
#  'banabananayeahbanana',
#  'banabananayeahwoohowoohwoohbanana',
#  'banana',
#  'band',
#  'bandin',
#  'bang',
#  'bangbow',
#  'bangkok',
#  'bangkokand',
#  'bank',
#  'bannok',
#  'bar',
#  'bare',
#  'bass',
#  'battl',
#  'bay',
#  'bayi',
#  'baykiwi',
#  'baymaori',
#  'baynic',
#  'bayturnt',
#  'be',
#  'beach',
#  'bear',
#  'bearknow',
#  'beask',
#  'beast',
#  'beat',
#  'beatin',
#  'beauti',
#  'beautifuland',
#  'beautifuldo',
#  'beautifulsunris',
#  'beautifulyour',
#  'becaus',
#  'becom',
#  'bed',
#  'bedtim',
#  'bee',
#  'been',
#  'beenif',
#  'beep',
#  'beeveryth',
#  'befor',
#  'beforecaus',
#  'beforei',
#  'beforeim',
#  'beforeoh',
#  'beg',
#  'beginn',
#  'beginnerstand',
#  'begun',
#  'behind',
#  'behindneed',
#  'behindwil',
#  'beim',
#  'beit',
#  'believ',
#  'believecaus',
#  'believei',
#  'believestay',
#  'believewhen',
#  'belong',
#  'belt',
#  'benadryl',
#  'bend',
#  'benz',
#  'benzo',
#  'beretta',
#  'berri',
#  'besid',
#  'best',
#  'bestbut',
#  'bestlisten',
#  'besttogeth',
#  'bet',
#  'betalk',
#  'bethen',
#  'better',
#  'betteral',
#  'bewhi',
#  'bexhil',
#  'beyond',
#  'big',
#  'bigbang',
#  'biggi',
#  'bigo',
#  'bigon',
#  'bike',
#  'billi',
#  'bird',
#  'birdcar',
#  'birdmayb',
#  'birdshel',
#  'birdso',
#  'birdsweet',
#  'birthday',
#  'birthim',
#  'bit',
#  'bitch',
#  'bitchesethre',
#  'bitchi',
#  'bitchyc',
#  'bkk',
#  'black',
#  'blah',
#  'blahand',
#  'blame',
#  'blameit',
#  'blank',
#  'blast',
#  'bleed',
#  'bleedingit',
#  'bless',
#  'blind',
#  'blindand',
#  'blinder',
#  'blindfor',
#  'blindmi',
#  'block',
#  'blockmak',
#  'bloodi',
#  'blow',
#  'blowi',
#  'blownand',
#  'blue',
#  'bluesbut',
#  'blunt',
#  'blur',
#  'bm',
#  'bnk',
#  'board',
#  'bodi',
#  'bodyget',
#  'bodyhow',
#  'boi',
#  'boicuz',
#  'bom',
#  'bomb',
#  'bombay',
#  'boneth',
#  'boo',
#  'booim',
#  'boom',
#  'boooh',
#  'boot',
#  'bore',
#  'born',
#  'borrowdreamsto',
#  'both',
#  'bottom',
#  'boundand',
#  'bout',
#  'bow',
#  'boxer',
#  'boy',
#  'boyi',
#  'boyiv',
#  'boysboy',
#  'br',
#  'brain',
#  'brandnam',
#  'brave',
#  'breadsugar',
#  'break',
#  'breakthrough',
#  'breakyou',
#  'breasttogeth',
#  'breath',
#  'breathcant',
#  'breathei',
#  'breathewhi',
#  'bright',
#  'brighter',
#  'bring',
#  'bringshold',
#  'british',
#  'bro',
#  'brobewar',
#  'broken',
#  'brolook',
#  'bronz',
#  'broshel',
#  'brother',
#  'brotherbuild',
#  'bruce',
#  'bruh',
#  'brush',
#  'bt',
#  'budget',
#  'bug',
#  'bugaoh',
#  'bugatti',
#  'bullshit',
#  'bumbl',
#  'bun',
#  'buri',
#  'burn',
#  'burnt',
#  'busi',
#  'but',
#  'butterfliesaint',
#  'butterfliesi',
#  'buy',
#  'buzz',
#  'by',
#  'bye',
#  'byewoh',
#  'byth',
#  'c',
#  'cage',
#  'cagefac',
#  'call',
#  'callingy',
#  'calm',
#  'came',
#  'cameand',
#  'camri',
#  'can',
#  'canabiscuit',
#  'canbrav',
#  'candi',
#  'caneveri',
#  'canreach',
#  'cant',
#  'capi',
#  'capo',
#  'car',
#  'card',
#  'care',
#  'carecom',
#  'carefuck',
#  'carei',
#  'careno',
#  'carri',
#  'casegel',
#  'cash',
#  'casio',
#  'castleafraid',
#  'castor',
#  'catch',
#  'caughtsurrend',
#  'caus',
#  'causebut',
#  'causei',
#  'cazi',
#  'cdsmoke',
#  'ce',
#  'ceil',
#  'celebr',
#  'celebrationwil',
#  'cellarwait',
#  'center',
#  'ceo',
#  'ceonumb',
#  'cg',
#  'champ',
#  'champagn',
#  'chanc',
#  'chanceil',
#  'chancelet',
#  'chancetherel',
#  'chang',
#  'changechorusit',
#  'changeddo',
#  'changeeveryon',
#  'changelov',
#  'changeso',
#  'changey',
#  'channel',
#  'chapo',
#  'charg',
#  'charli',
#  'chart',
#  'chase',
#  'chat',
#  'check',
#  'chees',
#  'chemi',
#  'chemic',
#  'chi',
#  'chick',
#  'chicken',
#  'chikau',
#  'child',
#  'childa',
#  'children',
#  'chill',
#  'chillin',
#  'chillturn',
#  'chin',
#  'choo',
#  'choru',
#  'chose',
#  'chosen',
#  'christma',
#  'church',
#  'cinderellasittin',
#  'citi',
#  'citiesmarch',
#  'citiessmil',
#  'cityw',
#  'clack',
#  'claimaim',
#  'clan',
#  'clap',
#  'clapw',
#  'class',
#  'classic',
#  'clear',
#  'clearli',
#  'clearyour',
#  'click',
#  'climb',
#  'clingto',
#  'cliqu',
#  'close',
#  'closer',
#  'closerahh',
#  'closerhey',
#  'cloth',
#  'cloud',
#  'club',
#  'cluesoh',
#  'cmon',
#  'co',
#  'coach',
#  'coat',
#  'code',
#  'codein',
#  'coffe',
#  'coffeey',
#  'coke',
#  'cold',
#  'coldmi',
#  'coldthen',
#  'color',
#  'combat',
#  'combolik',
#  'come',
#  'comedi',
#  'comedown',
#  'comfyfuck',
#  'commandgod',
#  'commando',
#  'common',
#  'como',
#  'complainsif',
#  'complet',
#  'complic',
#  'compromis',
#  'comradesw',
#  'concept',
#  'condit',
#  'confessi',
#  'confirm',
#  'confusedwhen',
#  'conli',
#  'connect',
#  'considerationsthen',
#  'contain',
#  'contemplatenow',
#  'contemplateon',
#  'contestantsnobodi',
#  'control',
#  'convers',
#  'conversationscaus',
#  'convinc',
#  'cooki',
#  'cool',
#  'copenhagen',
#  'corazon',
#  'cornerand',
#  'costtel',
#  'could',
#  'couldid',
#  'couldsay',
#  'count',
#  'counter',
#  'cover',
#  'coverim',
#  'covid',
#  'coz',
#  'cp',
#  'crapclaim',
#  'crash',
#  'crawl',
#  'crawliesit',
#  'crawliestak',
#  'cray',
#  'crazi',
#  'crazylet',
#  'crazyonc',
#  'crazyy',
#  'creationd',
#  'creationfli',
#  'creator',
#  'credit',
#  'creepi',
#  'crepsmandem',
#  'crew',
#  'crewgucci',
#  'cri',
#  'crib',
#  'criedjust',
#  'criedyour',
#  'crimin',
#  'crossedsettl',
#  'crowdeveri',
#  'crowdw',
#  'cruis',
#  'crush',
#  'crusin',
#  'cruz',
#  'crv',
#  'crya',
#  'crydoesnt',
#  'cryfor',
#  'cryhe',
#  'cryi',
#  'crylisten',
#  'cryno',
#  'cryoh',
#  'cryon',
#  'crypleas',
#  'crytel',
#  'crywhat',
#  'crywhi',
#  'cryyou',
#  'cultur',
#  'cunningham',
#  'cunt',
#  'cup',
#  'cupback',
#  'cupid',
#  'curtain',
#  'cut',
#  'cute',
#  'cuz',
#  'd',
#  'da',
#  'daboy',
#  'dad',
#  'daddi',
#  'dadidaladadadidaaoh',
#  'dae',
#  'daili',
#  'dailyvong',
#  'daisuki',
#  'dakara',
#  'damn',
#  'damnbang',
#  'danc',
#  'dancegood',
#  'dancingboy',
#  'dandelionand',
#  'danger',
#  'dare',
#  'dark',
#  'darknessto',
#  'darl',
#  'darlingif',
#  'darlingsay',
#  'dash',
#  'dat',
#  'data',
#  'dawn',
#  'day',
#  'dayonli',
#  'dayrap',
#  'daystwentyon',
#  'dayth',
#  'daytim',
#  'daytri',
#  'daytwentyon',
#  'dayup',
#  'daywhen',
#  'db',
#  'dc',
#  'de',
#  'deal',
#  'dealer',
#  'deang',
#  'dear',
#  'deari',
#  'dearlet',
#  'dearlost',
#  'deceasek',
#  'decolgen',
#  'decreasehi',
#  'deedsof',
#  'deep',
#  'deepheard',
#  'degre',
#  'dek',
#  'delic',
#  'delicateris',
#  'delici',
#  'deliv',
#  'deliveri',
#  'dem',
#  'deniedwhen',
#  'deniroesan',
#  'denni',
#  'denyif',
#  'depend',
#  'describ',
#  'deseasehit',
#  'desertw',
#  'deserv',
#  'design',
#  'desirebut',
#  'desirefar',
#  'despairno',
#  'despairto',
#  'desperationi',
#  'desserto',
#  'destinationthat',
#  'destini',
#  'destroy',
#  'detail',
#  'dia',
#  'diamondstud',
#  'dic',
#  'dich',
#  'dick',
#  'dickslick',
#  'did',
#  'didnt',
#  'die',
#  'differ',
#  'dig',
#  'digan',
#  'dinnerdont',
#  'dinnerkil',
#  'dior',
#  'dip',
#  'dippingtinkl',
#  'direct',
#  'directionknow',
#  'dirt',
#  'dirtandthat',
#  'dirti',
#  'disappearbut',
#  'diseas',
#  'disk',
#  'distressand',
#  'dive',
#  'dizzi',
#  'dj',
#  'dna',
#  'do',
#  'doand',
#  'dobut',
#  'doe',
#  'doesfre',
#  'doesnt',
#  'doesntnot',
#  'dofor',
#  'doi',
#  'dokey',
#  'dolifin',
#  'domi',
#  'don',
#  'done',
#  'doneyoul',
#  'dont',
#  'dontla',
#  'doo',
#  'dooco',
#  'doodooo',
#  'doohoo',
#  'dooit',
#  'dooo',
#  'door',
#  'doordo',
#  'doorit',
#  'doormi',
#  'doorto',
#  'dooyour',
#  'dope',
#  'doth',
#  'dou',
#  'doubl',
#  'doubt',
#  'doubti',
#  'down',
#  'downa',
#  'downahh',
#  'downal',
#  'downand',
#  'downbreak',
#  'downdo',
#  'downdown',
#  'downeverybodi',
#  'downfunni',
#  'downh',
#  'downher',
#  'downhil',
#  'downi',
#  'downim',
#  'downit',
#  'downjust',
#  'downkeep',
#  'downlif',
#  'downmi',
#  'downno',
#  'downremak',
#  'downso',
#  'downtel',
#  'downtri',
#  'downwhen',
#  'downyou',
#  'dowould',
#  'doy',
#  'doyou',
#  'doyour',
#  'dozen',
#  'dragoni',
#  'drama',
#  'dramatreat',
#  'drawn',
#  'dream',
#  'dreamal',
#  'dreamlandm',
#  'dreamsinc',
#  'dreamsit',
#  'dreamsmi',
#  'dreamstogeth',
#  'dress',
#  'drill',
#  'drink',
#  'drip',
#  'drive',
#  'drop',
#  'drown',
#  'drunken',
#  'du',
#  'dumbass',
#  'dumbfuck',
#  'dunk',
#  'dusti',
#  'dynamit',
#  'e',
#  'each',
#  'earplug',
#  'earsstrum',
#  'earth',
#  'eartha',
#  'easi',
#  'east',
#  'eastand',
#  'easyand',
#  'eat',
#  'eco',
#  'eden',
#  'edg',
#  'eesan',
#  'eh',
#  'eight',
#  'eightbang',
#  'el',
#  'eloqu',
#  'els',
#  'elseid',
#  'em',
#  'emot',
#  'emotioninsecur',
#  'empti',
#  'emptinesswer',
#  'enchant',
#  'end',
#  'endgam',
#  'endi',
#  'endoh',
#  'enemi',
#  'energi',
#  'energygirl',
#  'energyi',
#  'energyoh',
#  'energystand',
#  'enjoy',
#  'enjoycaus',
#  'enough',
#  'enoughim',
#  'entertain',
#  'entertainmentvkl',
#  'equal',
#  'errerr',
#  'erth',
#  'esan',
#  'esanheadband',
#  'escap',
#  'escobar',
#  'etc',
#  'eternityset',
#  'eve',
#  'even',
#  'ever',
#  'everestdo',
#  'everi',
#  'everjust',
#  'every',
#  'everybodi',
#  'everyday',
#  'everydayi',
#  'everydaymak',
#  'everydaywhat',
#  'everynight',
#  'everyth',
#  'everythingonli',
#  'everythingown',
#  'everythingwil',
#  'everythingy',
#  'everywher',
#  'everywhereno',
#  'everywhereoh',
#  'evil',
#  'evofhero',
#  'evryth',
#  'exciteeveri',
#  'excus',
#  'expect',
#  'extra',
#  'eye',
#  'eyesand',
#  'eyescu',
#  'eyesi',
#  'eyesit',
#  'eyestel',
#  'eyesto',
#  'eyeswhat',
#  'eyesy',
#  'eyesyour',
#  'f',
#  'face',
#  'facebook',
#  'facei',
#  'facekiss',
#  'fact',
#  'fade',
#  'faili',
#  'fair',
#  'fairi',
#  'fairim',
#  'fairytal',
#  'fairytaled',
#  ...]

# %%
# get highest weights
tfidf_df.sort_values('weight', ascending=False).head(5)
# Out:
#            word   weight
# 0             [  8.02153
# 8665     ฟันฟาง  8.02153
# 13113  เย็นชื่น  8.02153
# 8904      มาดาม  8.02153
# 8905    มาตรการ  8.02153

# %%
# assign tf idf scores to each song
tf_idf_vector = tfidf_transformer.transform(word_count_vector)

# attach count vectors to dataframe
tf_idf_vector_lst = [-1] * len(song_df)
for i in range(len(song_df)):
    tf_idf_vector_lst[i] = tf_idf_vector[i]
song_df['tf_idf_vector'] = tf_idf_vector_lst    

song_df['tf_idf_score'] = song_df['tf_idf_vector'].map(lambda vec: np.sum(vec.todense()))

# join valus to selected artists
song_filter_df = song_filter_df.join(song_df[['tf_idf_vector', 'tf_idf_score']])

# %%
tf_idf_vector.shape
# Out:
# (2240, 15042)

# %%
fig = px.box(song_filter_df, x='artist', y='tf_idf_score', title='TFIDF scores of songs per artist')
fig.show()

# %%
# calculate mean vector
def get_mean_vector(vec_lst):
    return csr_matrix(vstack(vec_lst).mean(axis=0))

# %%
# calculate mean vector over all songs of same artist
artist_df = song_df.groupby('artist').agg({'tf_idf_vector': get_mean_vector, 'song_name': len}).reset_index()\
                   .rename(columns={'song_name': 'n_songs'})

# get selected artists
artist_filter_df = artist_df.loc[artist_df['artist'].isin(song_filter_df['artist'])]

# %% [markdown]
# ### Similarity of Songs

# %%
similarity_matrix = cosine_similarity(vstack(artist_filter_df['tf_idf_vector']), 
                                      vstack(artist_filter_df['tf_idf_vector']))
artist_names = artist_filter_df['artist'].tolist()
fig = go.Figure(data=go.Heatmap(z=np.flipud(similarity_matrix), x=artist_names, y=list(reversed(artist_names)), 
                                colorscale='balance', zmin=0.5, zmax=1.1))

fig.update_layout(
    width=1500,
    height=1000,)
    
fig.show()

# %%
artist_filter_df
# Out:
#                artist                                      tf_idf_vector  \
# 0            25_hours    (0, 107)\t0.0033729404635357454\n  (0, 1071)...
# 1         add_carabao    (0, 1)\t0.01722099493446398\n  (0, 32)\t0.00...
# 2         ann_thitima    (0, 1)\t0.001205217775690307\n  (0, 207)\t0....
# 6             big_ass    (0, 592)\t0.012547968164130173\n  (0, 2146)\...
# 7      bird_thongchai    (0, 65)\t0.002947692762340396\n  (0, 93)\t0....
# 8               bnk48    (0, 40)\t0.011194993584758377\n  (0, 55)\t0....
# 9            bodyslam    (0, 3664)\t0.002646773914079035\n  (0, 3717)...
# 10            carabao    (0, 3661)\t0.0026894281128822055\n  (0, 3663...
# 11           cocktail    (0, 211)\t0.0029959778928084577\n  (0, 601)\...
# 12      da_endorphine    (0, 1)\t0.00047849201835692043\n  (0, 107)\t...
# 13      dunk_phunkorn    (0, 296)\t0.003153651455650734\n  (0, 1431)\...
# 16     film_rattapoom    (0, 1)\t0.0008609468518590861\n  (0, 28)\t0....
# 23       keng_tachaya    (0, 394)\t0.0013327503123862262\n  (0, 655)\...
# 24              klear    (0, 1)\t0.0036162945237876044\n  (0, 40)\t0....
# 25           labanoon    (0, 2146)\t0.016053350627419624\n  (0, 2211)...
# 28          lomosonic    (0, 274)\t0.0011745143495086828\n  (0, 1134)...
# 31       maew_jirasak    (0, 2273)\t0.0023289751610924446\n  (0, 2396...
# 33            mc_king    (0, 1)\t0.002786951129055462\n  (0, 29)\t0.0...
# 34           new_jiew    (0, 1)\t0.005668299351019474\n  (0, 65)\t0.0...
# 35   nicole_theriault    (0, 1)\t0.015933125274126787\n  (0, 2)\t0.00...
# 36          nut_meria    (0, 1229)\t0.0018638364673987204\n  (0, 3693...
# 37     pai_pongsatorn    (0, 605)\t0.001517210824884109\n  (0, 3666)\...
# 38            palapol    (0, 3766)\t0.0015839596986227547\n  (0, 3813...
# 39              palmy    (0, 635)\t0.00041751335045173344\n  (0, 655)...
# 40   panadda_ruangwut    (0, 1)\t0.000756241690218478\n  (0, 65)\t0.0...
# 42            paradox    (0, 211)\t0.004150357087548327\n  (0, 282)\t...
# 43     parn_thanaporn    (0, 3667)\t0.0021137829222821884\n  (0, 3682...
# 45      petch_saharat    (0, 896)\t0.0029304562620473882\n  (0, 3654)...
# 48         pu_pongsit    (0, 3657)\t0.0032702765271303467\n  (0, 3658...
# 51             scrubb    (0, 1044)\t0.0018785634031839248\n  (0, 1189...
# 52           sek_loso    (0, 465)\t0.00706915037046536\n  (0, 1046)\t...
# 53        silly_fools    (0, 1)\t0.0007376241297486502\n  (0, 2)\t0.0...
# 55       slot_machine    (0, 1)\t0.04012242638775083\n  (0, 6)\t0.004...
# 57  takkatan_chollada    (0, 3654)\t0.0018037936057794287\n  (0, 3666...
# 61            urboytj    (0, 1)\t0.021274178517486364\n  (0, 26)\t0.0...
# 62                vkl    (0, 0)\t0.0010370284886534816\n  (0, 1)\t0.0...
# 63      wan_thanakrit    (0, 540)\t0.006913981315190571\n  (0, 1046)\...
#
#     n_songs
# 0        35
# 1        35
# 2        35
# 6        35
# 7        35
# 8        35
# 9        35
# 10       35
# 11       35
# 12       35
# 13       35
# 16       35
# 23       35
# 24       35
# 25       35
# 28       35
# 31       35
# 33       35
# 34       35
# 35       35
# 36       35
# 37       35
# 38       35
# 39       35
# 40       35
# 42       35
# 43       35
# 45       35
# 48       35
# 51       35
# 52       35
# 53       35
# 55       35
# 57       35
# 61       35
# 62       35
# 63       35

# %%
song_filter_df.sample(5)
# Out:
#              artist            song_name                    href  \
# 540          scrubb                  หนี  /music/thailyric/18133
# 1693       25_hours          แรงโน้มถ่วง  /music/thailyric/10479
# 1129  petch_saharat               โง่เอง  /music/thailyric/14295
# 2153      nut_meria  เปลี่ยนใจไม่ได้แล้ว   /music/thailyric/2323
# 1513  da_endorphine         รักครั้งใหม่   /music/thailyric/1604
#
#                                                   lyric  lines  \
# 540   ในความทรงจำ ฉันยืนอยู่ในวัน\rเมื่อวานตอนที่เรา...     26
# 1693  บินไปในท้องนภา ให้ไกลจนลับสายตา\rเดินทางไปบนดว...     41
# 1129  บ่แม่นดีเอสไอ เลยสืบบ่ได้ว่าคนร้ายคือเธอ\rลอบส...     37
# 2153  เธอพูดใช่มั้ย ใช่มั้ย\rใช่มั้ย นี่เธอนึกยังไงก...     81
# 1513  รักวันวานในความเจ็บช้ำ\rเคยทำให้คนอย่างฉันลำบา...     26
#
#                                                   words  n_words  \
# 540   [ใน, ความทรงจำ, ฉัน, ยืน, อยู่, ใน, วัน, เมื่อ...      151
# 1693  [บิน, ไป, ใน, ท้อง, นภา, ให้, ไกล, จน, ลับสายต...      310
# 1129  [บ่, แม่น, ดีเอสไอ, เลย, สืบ, บ่, ได้, ว่า, คน...      257
# 2153  [เธอ, พูด, ใช่, มั้ย, ใช่, มั้ย, ใช่, มั้ย, นี...      384
# 1513  [รัก, วันวาน, ใน, ความเจ็บช้ำ, เคย, ทำให้, คน,...      168
#
#                                               words_str          artists  \
# 540   ใน ความทรงจำ ฉัน ยืน อยู่ ใน วัน เมื่อวาน ตอนท...         {scrubb}
# 1693  บิน ไป ใน ท้อง นภา ให้ ไกล จน ลับสายตา เดินทาง...       {25_hours}
# 1129  บ่ แม่น ดีเอสไอ เลย สืบ บ่ ได้ ว่า คนร้าย คือ ...  {petch_saharat}
# 2153  เธอ พูด ใช่ มั้ย ใช่ มั้ย ใช่ มั้ย นี่ เธอ นึก...      {nut_meria}
# 1513  รัก วันวาน ใน ความเจ็บช้ำ เคย ทำให้ คน อย่าง ฉ...  {da_endorphine}
#
#       duplicates  n_artists  unique_words_ratio  words_per_line  \
# 540            0          1            0.397351        5.807692
# 1693           0          1            0.229032        7.560976
# 1129           0          1            0.342412        6.945946
# 2153           0          1            0.247396        4.740741
# 1513           0          1            0.476190        6.461538
#
#                                           tf_idf_vector  tf_idf_score
# 540     (0, 14958)\t0.10753700672422206\n  (0, 14855...      6.870686
# 1693    (0, 14986)\t0.060684729336324794\n  (0, 1495...      2.979150
# 1129    (0, 15006)\t0.011420958483154792\n  (0, 1493...      5.053104
# 2153    (0, 15006)\t0.01164013275703079\n  (0, 14986...      6.273115
# 1513    (0, 14973)\t0.03789787550661723\n  (0, 14958...      7.577964

# %%
artist_song_filter_df = pd.merge(artist_filter_df[['artist', 'tf_idf_vector', 'n_songs']].assign(key = 0), 
                                 song_filter_df[['artist', 'tf_idf_vector', 'song_name']].assign(key = 0), on='key', 
                                 suffixes=['_artist', '_song']).drop('key', axis=1).reset_index(drop=True)

artist_song_filter_df['same_artist'] = artist_song_filter_df['artist_artist'] == artist_song_filter_df['artist_song']

# %%
artist_song_filter_df[artist_song_filter_df['same_artist']==False].head()
# Out:
#   artist_artist                               tf_idf_vector_artist  n_songs  \
# 0      25_hours    (0, 107)\t0.0033729404635357454\n  (0, 1071)...       35
# 1      25_hours    (0, 107)\t0.0033729404635357454\n  (0, 1071)...       35
# 2      25_hours    (0, 107)\t0.0033729404635357454\n  (0, 1071)...       35
# 3      25_hours    (0, 107)\t0.0033729404635357454\n  (0, 1071)...       35
# 4      25_hours    (0, 107)\t0.0033729404635357454\n  (0, 1071)...       35
#
#       artist_song                                 tf_idf_vector_song  \
# 0  bird_thongchai    (0, 14986)\t0.02706318124303119\n  (0, 14978...
# 1  bird_thongchai    (0, 14973)\t0.07331503970888636\n  (0, 14914...
# 2  bird_thongchai    (0, 14978)\t0.0895602203600452\n  (0, 14973)...
# 3  bird_thongchai    (0, 14978)\t0.08974985827768892\n  (0, 14973...
# 4  bird_thongchai    (0, 14973)\t0.033155545848114705\n  (0, 1488...
#
#      song_name  same_artist
# 0         Okay        False
# 1  กว่าจักรวาล        False
# 2        กำแพง        False
# 3  ชีวิตเดี่ยว        False
# 4    ผู้ต้องหา        False

# %%
# calculate similarity of artist tf idf vector and song vector
def tf_idf_vector_similarity(artist_vector, song_vector, songs, same_artist):
    # check if song is from same artist
    if same_artist:
        # deduct song vector from artist vector
        artist_vector = (songs * artist_vector - song_vector) / (songs - 1)
    # calculate similarity
    return cosine_similarity(artist_vector, song_vector)[0][0]

# %%
artist_song_filter_df['vector_similarity'] = artist_song_filter_df.apply(lambda row: tf_idf_vector_similarity(row['tf_idf_vector_artist'], 
                                                                     row['tf_idf_vector_song'], 
                                                                     row['n_songs'], row['same_artist']), axis=1)

# This function may take longer than 8 minutes.

# %%
df = artist_song_filter_df

fig = go.Figure()

fig.add_trace(go.Violin(x=df['artist_artist'][df['same_artist']],
                        y=df['vector_similarity'][df['same_artist']],
                        legendgroup='Same Artist', scalegroup='Same Artist', name='Same Artist',
                        side='negative')
             )
fig.add_trace(go.Violin(x=df['artist_artist'][~df['same_artist']],
                        y=df['vector_similarity'][~df['same_artist']],
                        legendgroup='Different Artists', scalegroup='Different Artists', name='Different Artists',
                        side='positive')
             )


fig.update_layout(
    width=2000,
    height=800,)
fig.update_traces(meanline_visible=True)
fig.update_layout(violingap=0, violinmode='overlay')
fig.update_layout(title='Similarity of Songs')
fig.update_xaxes(range=[-0.5, 9.5])
fig.update_yaxes(range=[-0.1, 0.8], title='Similarity')
fig.show()

# Note that you should click *Autoscale* on the figure option to show all artists' violins

# %% [markdown]
# ## Sentiment analysis

# %%
# polarity_lst = [-1] * len(song_df)
# subjectivity_lst = [-1] * len(song_df)

# for i, text in enumerate(song_df['lyric']):
#     sentiment = TextBlob(text)
#     polarity_lst[i] = sentiment.polarity
#     subjectivity_lst[i] = sentiment.subjectivity
    
# song_df['polarity'] = polarity_lst
# song_df['subjectivity'] = subjectivity_lst

# song_filter_df = song_filter_df.join(song_df[['polarity', 'subjectivity']])

# %% [markdown]
# ### Polarity and Subjectivity of Songs

# %%
# fig = px.scatter(song_filter_df, x='polarity', y='subjectivity', color='artist', hover_data=['song_name'], title='Polarity and Subjectivity of Songs')
# fig.show()

# %% [markdown]
# ### Polarity by artist

# %%
# fig = px.box(song_filter_df, x='artist', y='polarity', title='Polarity by artist')
# fig.show()

# %%
# song_filter_df

# %% [markdown]
# ## Export the feature-extracted data

# %%
song_df.to_pickle('../../data_lyrics/pd/fx_th_songs_35.pkl')
