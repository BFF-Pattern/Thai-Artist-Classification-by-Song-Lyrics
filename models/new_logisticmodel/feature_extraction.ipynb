# %% [markdown]
# ### Import Library

# %%
# import libraries
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import random
from scipy.sparse import csr_matrix, vstack
# from textblob import TextBlob
# from langdetect import detect_langs
import pickle

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Import the clean data

# %%
song_df = pd.read_pickle('../../data_lyrics/pd/clean_th_songs.pkl')

# %%
song_df.dtypes
# Out:
# artist        object
# song_name     object
# href          object
# lyric         object
# lines          int64
# words         object
# n_words        int64
# words_str     object
# artists       object
# duplicates     int64
# n_artists      int64
# dtype: object

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Number of words

# %%
n_artist = len(song_df['artist'].unique())
random.seed(0)

artist_select = random.choices(song_df['artist'].unique(), k=n_artist)

song_filter_df = song_df.loc[song_df['artist'].isin(artist_select)]
print('Total number of songs: {}'.format(len(song_filter_df)))
song_filter_df.groupby('artist')[['song_name']].count().reset_index().rename(columns={'song_name':'n_songs'})
# Out:
# Total number of songs: 1295
#                artist  n_songs
# 0            25_hours       35
# 1         add_carabao       35
# 2         ann_thitima       35
# 3             big_ass       35
# 4      bird_thongchai       35
# 5               bnk48       35
# 6            bodyslam       35
# 7             carabao       35
# 8            cocktail       35
# 9       da_endorphine       35
# 10      dunk_phunkorn       35
# 11     film_rattapoom       35
# 12       keng_tachaya       35
# 13              klear       35
# 14           labanoon       35
# 15          lomosonic       35
# 16       maew_jirasak       35
# 17            mc_king       35
# 18           new_jiew       35
# 19   nicole_theriault       35
# 20          nut_meria       35
# 21     pai_pongsatorn       35
# 22            palapol       35
# 23              palmy       35
# 24   panadda_ruangwut       35
# 25            paradox       35
# 26     parn_thanaporn       35
# 27      petch_saharat       35
# 28         pu_pongsit       35
# 29             scrubb       35
# 30           sek_loso       35
# 31        silly_fools       35
# 32       slot_machine       35
# 33  takkatan_chollada       35
# 34            urboytj       35
# 35                vkl       35
# 36      wan_thanakrit       35

# %%
fig = px.box(song_filter_df, x='artist', y='n_words', title='Word count per song by artist')
fig.show()

# %% [markdown]
# ### Repeated

# %%
# number of unique stems
song_df['n_unique_words'] = song_df['words'].map(lambda lst: len(set(lst)))

# ratio of unique stems
song_df['unique_words_ratio'] = song_df['n_unique_words'] / song_df['n_words']

# attach column to selected artists
song_filter_df = song_filter_df.join(song_df['unique_words_ratio'])

# %%
fig = px.box(song_filter_df, x='artist', y='unique_words_ratio', title='Ratio of unique words to all words')
fig.show()

# %% [markdown]
# ### Words per line

# %%
# calculate number of words per line
song_df['words_per_line'] = song_df['n_words'] / song_df['lines'].astype(float)

song_filter_df = song_filter_df.join(song_df['words_per_line'])

# %%
fig = px.box(song_filter_df, x='artist', y='words_per_line', title='Words per line')
fig.show()

# %% [markdown]
# ## TFIDF

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
# initialise count vectorizer
cv = CountVectorizer(analyzer=lambda x:x.split())

word_count_vector = cv.fit_transform(song_df['words_str'])

# compute idf
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
# print idf values
tfidf_df = pd.DataFrame({'word': cv.get_feature_names(), 'weight': tfidf_transformer.idf_})
 
# get lowest weights
tfidf_df.sort_values('weight').head()
# Out:
# c:\Users\FACT-PC\anaconda3\envs\torch38\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#       word    weight
# 13370  ไม่  1.100365
# 5494   ที่  1.170345
# 3815    จะ  1.186346
# 13339   ไป  1.191737
# 13219  ให้  1.210286

# %%
cv.get_feature_names()
# Out:
# c:\Users\FACT-PC\anaconda3\envs\torch38\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
# ['[',
#  'a',
#  'about',
#  'abov',
#  'absolut',
#  'accent',
#  'accept',
#  'accessori',
#  'ace',
#  'achiev',
#  'across',
#  'act',
#  'action',
#  'ad',
#  'adapt',
#  'addi',
#  'addict',
#  'address',
#  'adventur',
#  'aey',
#  'afraid',
#  'after',
#  'again',
#  'agent',
#  'agre',
#  'ah',
#  'aha',
#  'ahead',
#  'ahh',
#  'ai',
#  'aim',
#  'aint',
#  'air',
#  'airlin',
#  'aitakatta',
#  'aixd',
#  'ak',
#  'album',
#  'alcohol',
#  'alert',
#  'alexand',
#  'aliv',
#  'all',
#  'alley',
#  'allow',
#  'alon',
#  'along',
#  'alreadi',
#  'alright',
#  'alskar',
#  'although',
#  'alway',
#  'am',
#  'america',
#  'among',
#  'amot',
#  'amp',
#  'an',
#  'anata',
#  'and',
#  'angel',
#  'ani',
#  'anim',
#  'ann',
#  'anoth',
#  'answer',
#  'anybodi',
#  'anymor',
#  'anyon',
#  'anyth',
#  'anytim',
#  'anyway',
#  'aouuu',
#  'ap',
#  'apart',
#  'app',
#  'appealin',
#  'appear',
#  'applic',
#  'appreci',
#  'approach',
#  'aquaman',
#  'archer',
#  'are',
#  'ark',
#  'arm',
#  'armi',
#  'armour',
#  'around',
#  'art',
#  'artist',
#  'as',
#  'asian',
#  'ask',
#  'ass',
#  'at',
#  'attack',
#  'attitud',
#  'attract',
#  'auckland',
#  'audi',
#  'auto',
#  'autotun',
#  'aw',
#  'awak',
#  'award',
#  'away',
#  'ay',
#  'aye',
#  'b',
#  'babe',
#  'babi',
#  'babyhey',
#  'back',
#  'backward',
#  'bad',
#  'bae',
#  'bag',
#  'balen',
#  'ball',
#  'bambam',
#  'banabananayeah',
#  'banana',
#  'band',
#  'bang',
#  'bangkok',
#  'bank',
#  'bannok',
#  'bar',
#  'bare',
#  'bass',
#  'battl',
#  'bay',
#  'be',
#  'beach',
#  'bear',
#  'beast',
#  'beat',
#  'beatin',
#  'beauti',
#  'becaus',
#  'becom',
#  'bed',
#  'bee',
#  'been',
#  'beep',
#  'befor',
#  'beg',
#  'beginn',
#  'begun',
#  'behind',
#  'believ',
#  'belong',
#  'belt',
#  'benadryl',
#  'bend',
#  'benz',
#  'benzo',
#  'beretta',
#  'berri',
#  'besid',
#  'best',
#  'bet',
#  'better',
#  'bewar',
#  'bexhil',
#  'beyond',
#  'big',
#  'bigbang',
#  'biggi',
#  'bigo',
#  'bike',
#  'billi',
#  'bird',
#  'birth',
#  'birthday',
#  'bit',
#  'bitch',
#  'bitches',
#  'bitchi',
#  'bkk',
#  'black',
#  'blah',
#  'blame',
#  'blank',
#  'blast',
#  'bleed',
#  'bless',
#  'blind',
#  'blinder',
#  'bling',
#  'block',
#  'bloodi',
#  'blow',
#  'blown',
#  'blue',
#  'blunt',
#  'blur',
#  'bm',
#  'bnk',
#  'board',
#  'bodi',
#  'boi',
#  'bom',
#  'bomb',
#  'bombay',
#  'bone',
#  'boo',
#  'boom',
#  'boot',
#  'bore',
#  'born',
#  'borrow',
#  'both',
#  'bottom',
#  'bound',
#  'bout',
#  'bow',
#  'boxer',
#  'boy',
#  'br',
#  'brain',
#  'brandnam',
#  'brave',
#  'bread',
#  'break',
#  'breast',
#  'breath',
#  'bright',
#  'brighter',
#  'bring',
#  'british',
#  'bro',
#  'broken',
#  'bronz',
#  'brother',
#  'brought',
#  'bruce',
#  'bruh',
#  'brush',
#  'bt',
#  'budget',
#  'bug',
#  'buga',
#  'bugaboo',
#  'bugatti',
#  'build',
#  'bullshit',
#  'bumbl',
#  'bun',
#  'burger',
#  'buri',
#  'burn',
#  'burnt',
#  'busi',
#  'but',
#  'butterfli',
#  'buy',
#  'buzz',
#  'by',
#  'bye',
#  'c',
#  'cage',
#  'call',
#  'calm',
#  'came',
#  'camri',
#  'can',
#  'canabiscuit',
#  'candi',
#  'cant',
#  'cap',
#  'capo',
#  'car',
#  'card',
#  'care',
#  'carri',
#  'case',
#  'cash',
#  'casio',
#  'castl',
#  'castor',
#  'catch',
#  'catier',
#  'caught',
#  'caus',
#  'cazi',
#  'cd',
#  'ce',
#  'ceil',
#  'celebr',
#  'cellar',
#  'center',
#  'ceo',
#  'cg',
#  'champ',
#  'champagn',
#  'chanc',
#  'chang',
#  'channel',
#  'chapo',
#  'charg',
#  'charli',
#  'chart',
#  'chase',
#  'chat',
#  'check',
#  'chees',
#  'chemi',
#  'chemic',
#  'chi',
#  'chick',
#  'chicken',
#  'chikau',
#  'child',
#  'children',
#  'chill',
#  'chillin',
#  'chin',
#  'choo',
#  'choru',
#  'chose',
#  'chosen',
#  'christma',
#  'church',
#  'cinderella',
#  'citi',
#  'clack',
#  'claim',
#  'clan',
#  'clap',
#  'class',
#  'classic',
#  'clear',
#  'clearli',
#  'click',
#  'climb',
#  'cling',
#  'cliqu',
#  'close',
#  'closer',
#  'cloth',
#  'cloud',
#  'club',
#  'clue',
#  'cmon',
#  'co',
#  'coach',
#  'coat',
#  'code',
#  'codein',
#  'coffe',
#  'coke',
#  'cold',
#  'color',
#  'combat',
#  'combo',
#  'come',
#  'comedi',
#  'comfi',
#  'command',
#  'commando',
#  'common',
#  'como',
#  'complain',
#  'complet',
#  'complic',
#  'compromis',
#  'comrad',
#  'concept',
#  'condit',
#  'confess',
#  'confirm',
#  'confus',
#  'conli',
#  'connect',
#  'consider',
#  'contain',
#  'contempl',
#  'contest',
#  'control',
#  'convers',
#  'convinc',
#  'cooki',
#  'cool',
#  'copenhagen',
#  'corazon',
#  'corner',
#  'cost',
#  'could',
#  'count',
#  'counter',
#  'cover',
#  'covid',
#  'coz',
#  'cp',
#  'crap',
#  'crash',
#  'crawl',
#  'crawli',
#  'cray',
#  'crazi',
#  'creation',
#  'creator',
#  'credit',
#  'creepi',
#  'crep',
#  'crew',
#  'cri',
#  'crib',
#  'crimin',
#  'cross',
#  'crowd',
#  'crown',
#  'cruis',
#  'crush',
#  'crusin',
#  'cruz',
#  'crv',
#  'cryno',
#  'cu',
#  'cultur',
#  'cunningham',
#  'cunt',
#  'cup',
#  'cupid',
#  'curtain',
#  'cut',
#  'cute',
#  'cuz',
#  'd',
#  'da',
#  'daboy',
#  'dad',
#  'daddi',
#  'dadidaladadadidaa',
#  'dae',
#  'daili',
#  'daisuki',
#  'dakara',
#  'damn',
#  'danc',
#  'dandelion',
#  'danger',
#  'dare',
#  'dark',
#  'darl',
#  'dash',
#  'dat',
#  'data',
#  'dawn',
#  'day',
#  'daytim',
#  'db',
#  'dc',
#  'de',
#  'deal',
#  'dealer',
#  'deang',
#  'dear',
#  'deceas',
#  'decolgen',
#  'decreas',
#  'deed',
#  'deep',
#  'degre',
#  'dek',
#  'delic',
#  'delici',
#  'deliv',
#  'deliveri',
#  'dem',
#  'deni',
#  'deniro',
#  'denni',
#  'depend',
#  'describ',
#  'deseas',
#  'desert',
#  'deserv',
#  'design',
#  'desir',
#  'despair',
#  'despairno',
#  'desper',
#  'desserto',
#  'destin',
#  'destini',
#  'destroy',
#  'detail',
#  'dia',
#  'diamondstud',
#  'dic',
#  'dich',
#  'dick',
#  'did',
#  'didnt',
#  'die',
#  'differ',
#  'dig',
#  'digan',
#  'dinner',
#  'dior',
#  'dip',
#  'direct',
#  'dirt',
#  'dirti',
#  'disappear',
#  'diseas',
#  'disk',
#  'distress',
#  'dive',
#  'dizzi',
#  'dj',
#  'dna',
#  'do',
#  'doe',
#  'doesnt',
#  'dokey',
#  'don',
#  'done',
#  'dont',
#  'doo',
#  'dooo',
#  'door',
#  'dope',
#  'dou',
#  'doubl',
#  'doubt',
#  'down',
#  'downhil',
#  'dozen',
#  'dragon',
#  'drama',
#  'drawn',
#  'dream',
#  'dreamin',
#  'dreamland',
#  'dreamsto',
#  'dress',
#  'drill',
#  'drink',
#  'drip',
#  'drippin',
#  'drive',
#  'drop',
#  'drown',
#  'drunken',
#  'du',
#  'dude',
#  'dumbass',
#  'dumbfuck',
#  'dunk',
#  'dusti',
#  'dynamit',
#  'e',
#  'each',
#  'ear',
#  'earplug',
#  'earth',
#  'easi',
#  'east',
#  'eat',
#  'eco',
#  'eden',
#  'edg',
#  'eh',
#  'eight',
#  'el',
#  'eloqu',
#  'els',
#  'em',
#  'embrac',
#  'emot',
#  'empti',
#  'enchant',
#  'end',
#  'endgam',
#  'enemi',
#  'energi',
#  'enjoy',
#  'enough',
#  'entertain',
#  'equal',
#  'errerr',
#  'erth',
#  'esan',
#  'escap',
#  'escobar',
#  'etc',
#  'etern',
#  'eve',
#  'even',
#  'ever',
#  'everest',
#  'everi',
#  'everybodi',
#  'everyday',
#  'everynight',
#  'everyon',
#  'everyth',
#  'everywher',
#  'evil',
#  'evo',
#  'evryth',
#  'excit',
#  'excus',
#  'expect',
#  'extra',
#  'eye',
#  'f',
#  'face',
#  'facebook',
#  'fact',
#  'fade',
#  'fail',
#  'fair',
#  'fairi',
#  'fairytal',
#  'faith',
#  'fakahol',
#  'fake',
#  'fall',
#  'fallen',
#  'fam',
#  'fame',
#  'famili',
#  'familia',
#  'fan',
#  'fanci',
#  'fantas',
#  'far',
#  'farm',
#  'farri',
#  'fascism',
#  'fashion',
#  'fast',
#  'faster',
#  'fat',
#  'fate',
#  'fault',
#  'favorit',
#  'fc',
#  'fear',
#  'feat',
#  'feed',
#  'feel',
#  'feelin',
#  'feet',
#  'fell',
#  'felt',
#  'ferrari',
#  'festiv',
#  'few',
#  'fhero',
#  'fiber',
#  'fight',
#  'figur',
#  'fiji',
#  'fill',
#  'filter',
#  'final',
#  'find',
#  'fine',
#  'fino',
#  'fir',
#  'fire',
#  'first',
#  'fit',
#  'five',
#  'fix',
#  'flame',
#  'flavor',
#  'fle',
#  'flex',
#  'flexin',
#  'fli',
#  'flight',
#  'flip',
#  'flirt',
#  'floor',
#  'flop',
#  'flow',
#  'flower',
#  'flyin',
#  'focu',
#  'focus',
#  'follow',
#  'fool',
#  'footbal',
#  'for',
#  'forb',
#  'fore',
#  'forehead',
#  'forest',
#  'forev',
#  'forget',
#  'forgiv',
#  'fortun',
#  'fosho',
#  'found',
#  'four',
#  'fourti',
#  'frail',
#  'frame',
#  'francisco',
#  'fray',
#  'freak',
#  'free',
#  'freez',
#  'fresh',
#  'friday',
#  'fridg',
#  'friend',
#  'from',
#  'front',
#  'frown',
#  'froze',
#  'frozen',
#  'fuck',
#  'fucka',
#  'fuckahol',
#  'fuckin',
#  'full',
#  'fun',
#  'funki',
#  'funni',
#  'furiou',
#  'furnitur',
#  'fuse',
#  'futur',
#  'fxxk',
#  'g',
#  'ga',
#  'gain',
#  'game',
#  'gamer',
#  'gang',
#  'gap',
#  'gari',
#  'gave',
#  'gavind',
#  'ged',
#  'gel',
#  'gemini',
#  'gener',
#  'geni',
#  'gentleman',
#  'get',
#  'gg',
#  'ghetto',
#  'ghost',
#  'gi',
#  'girl',
#  'girlfriend',
#  'girlsbitchi',
#  'give',
#  'glam',
#  'glass',
#  'glock',
#  'glori',
#  'glow',
#  'go',
#  'goat',
#  'god',
#  'goe',
#  'goin',
#  'gold',
#  'golden',
#  'gon',
#  'gone',
#  'gonna',
#  'good',
#  'goodby',
#  'goodnight',
#  'googl',
#  'got',
#  'gothic',
#  'gotta',
#  'grab',
#  'grant',
#  'grave',
#  'graviti',
#  'great',
#  'green',
#  'grief',
#  'griev',
#  'grind',
#  'groov',
#  'groovi',
#  'ground',
#  'grow',
#  'grown',
#  'gu',
#  'gucci',
#  'guess',
#  'guid',
#  'guitar',
#  'gun',
#  'gut',
#  'guy',
#  'gym',
#  'h',
#  'ha',
#  'haato',
#  'had',
#  'hah',
#  'haha',
#  'half',
#  'hallow',
#  'hamburg',
#  'hand',
#  'handl',
#  'handsom',
#  'hang',
#  'hao',
#  'happend',
#  'happi',
#  'hard',
#  'harder',
#  'hardli',
#  'harmoni',
#  'harri',
#  'hat',
#  'hate',
#  'hater',
#  'hatin',
#  'haunt',
#  'have',
#  'havent',
#  'hay',
#  'he',
#  'head',
#  'headband',
#  'headshot',
#  'heal',
#  'hear',
#  'heard',
#  'heart',
#  'heartbreak',
#  'heat',
#  'heater',
#  'heath',
#  'heaven',
#  'heavi',
#  'hee',
#  'heel',
#  'heineken',
#  'hell',
#  'hello',
#  'help',
#  'hemispher',
#  'hennessi',
#  'henni',
#  'henri',
#  'her',
#  'herbalist',
#  'here',
#  'hero',
#  'hesit',
#  'hey',
#  'hi',
#  'hide',
#  'high',
#  'higher',
#  'hill',
#  'him',
#  'hip',
#  'hiphop',
#  'hiphopp',
#  'hiso',
#  'histori',
#  'hit',
#  'hmmm',
#  'ho',
#  'hobbi',
#  'hoe',
#  'hold',
#  'holi',
#  'holiday',
#  'holla',
#  'home',
#  'homeward',
#  'homi',
#  'honey',
#  'hoo',
#  'hood',
#  'hook',
#  'hop',
#  'hope',
#  'hopeless',
#  'hors',
#  'hot',
#  'hotspot',
#  'hour',
#  'how',
#  'hub',
#  'hug',
#  'hum',
#  'human',
#  'hummingbird',
#  'hundr',
#  'hunger',
#  'hungri',
#  'hunni',
#  'hunt',
#  'hurt',
#  'hybrid',
#  'hype',
#  'i',
#  'ib',
#  'iberri',
#  'ice',
#  'ich',
#  'id',
#  'idea',
#  'if',
#  'ig',
#  'igcs',
#  'ignor',
#  'ii',
#  'iil',
#  'il',
#  'ill',
#  'im',
#  'ima',
#  'imagin',
#  'imma',
#  'immort',
#  'imperfect',
#  'importa',
#  'imposs',
#  'improv',
#  'in',
#  'independ',
#  'indi',
#  'industri',
#  'infin',
#  'inner',
#  'innoc',
#  'insan',
#  'insecur',
#  'insid',
#  'inspir',
#  'intimid',
#  'into',
#  'involv',
#  'is',
#  'island',
#  'isr',
#  'issu',
#  'it',
#  'itd',
#  'item',
#  'itll',
#  'ive',
#  'j',
#  'ja',
#  'jabaja',
#  'jack',
#  'jag',
#  'jam',
#  'jazz',
#  'je',
#  'jesu',
#  'jetlag',
#  'jetskii',
#  'ji',
#  'jiggo',
#  'job',
#  'john',
#  'join',
#  'joint',
#  'jordan',
#  'josh',
#  'joy',
#  'juliet',
#  'jump',
#  'june',
#  'jurass',
#  'just',
#  'justic',
#  'k',
#  'kang',
#  'kangaeteta',
#  'karma',
#  'ke',
#  'keat',
#  'keep',
#  'key',
#  'kfc',
#  'khao',
#  'kick',
#  'kid',
#  'kiddo',
#  'kill',
#  'killin',
#  'kimi',
#  'kind',
#  'king',
#  ...]

# %%
# get highest weights
tfidf_df.sort_values('weight', ascending=False).head(5)
# Out:
#         word   weight
# 0          [  8.02153
# 7153     พูล  8.02153
# 7184  ฟักไข่  8.02153
# 7183  ฟักทอง  8.02153
# 7180     ฟอง  8.02153

# %%
# assign tf idf scores to each song
tf_idf_vector = tfidf_transformer.transform(word_count_vector)

# attach count vectors to dataframe
tf_idf_vector_lst = [-1] * len(song_df)
for i in range(len(song_df)):
    tf_idf_vector_lst[i] = tf_idf_vector[i]
song_df['tf_idf_vector'] = tf_idf_vector_lst    

song_df['tf_idf_score'] = song_df['tf_idf_vector'].map(lambda vec: np.sum(vec.todense()))

# join valus to selected artists
song_filter_df = song_filter_df.join(song_df[['tf_idf_vector', 'tf_idf_score']])

# %%
tf_idf_vector.shape
# Out:
# (2240, 13513)

# %%
fig = px.box(song_filter_df, x='artist', y='tf_idf_score', title='TFIDF scores of songs per artist')
fig.show()

# %%
# calculate mean vector
def get_mean_vector(vec_lst):
    return csr_matrix(vstack(vec_lst).mean(axis=0))

# %%
# calculate mean vector over all songs of same artist
artist_df = song_df.groupby('artist').agg({'tf_idf_vector': get_mean_vector, 'song_name': len}).reset_index()\
                   .rename(columns={'song_name': 'n_songs'})

# get selected artists
artist_filter_df = artist_df.loc[artist_df['artist'].isin(song_filter_df['artist'])]

# %% [markdown]
# ### Similarity of Songs

# %%
similarity_matrix = cosine_similarity(vstack(artist_filter_df['tf_idf_vector']), 
                                      vstack(artist_filter_df['tf_idf_vector']))
artist_names = artist_filter_df['artist'].tolist()
fig = go.Figure(data=go.Heatmap(z=np.flipud(similarity_matrix), x=artist_names, y=list(reversed(artist_names)), 
                                colorscale='balance', zmin=0.5, zmax=1.1))

fig.update_layout(
    width=1500,
    height=1000,)
    
fig.show()

# %%
artist_filter_df
# Out:
#                artist                                      tf_idf_vector  \
# 0            25_hours    (0, 59)\t0.004297334094741244\n  (0, 662)\t0...
# 1         add_carabao    (0, 1)\t0.014633107002671019\n  (0, 21)\t0.0...
# 2         ann_thitima    (0, 1)\t0.001199627225432793\n  (0, 109)\t0....
# 6             big_ass    (0, 357)\t0.012350142704695559\n  (0, 1269)\...
# 7      bird_thongchai    (0, 42)\t0.002626827414628101\n  (0, 51)\t0....
# 8               bnk48    (0, 11)\t0.0010226403195978766\n  (0, 25)\t0...
# 9            bodyslam    (0, 2207)\t0.00264755348775342\n  (0, 2260)\...
# 10            carabao    (0, 2204)\t0.0026893738911699747\n  (0, 2206...
# 11           cocktail    (0, 111)\t0.004789324582297804\n  (0, 365)\t...
# 12      da_endorphine    (0, 1)\t0.00044912663312639327\n  (0, 59)\t0...
# 13      dunk_phunkorn    (0, 146)\t0.002992884052844867\n  (0, 860)\t...
# 16     film_rattapoom    (0, 1)\t0.0008101205350405075\n  (0, 18)\t0....
# 23       keng_tachaya    (0, 207)\t0.0012756093894699411\n  (0, 408)\...
# 24              klear    (0, 1)\t0.003588923496458914\n  (0, 25)\t0.0...
# 25           labanoon    (0, 1269)\t0.01567516194732454\n  (0, 1294)\...
# 28          lomosonic    (0, 133)\t0.0011560014335138388\n  (0, 285)\...
# 31       maew_jirasak    (0, 1310)\t0.0022838607374250724\n  (0, 1390...
# 33            mc_king    (0, 1)\t0.002774332547575245\n  (0, 19)\t0.0...
# 34           new_jiew    (0, 1)\t0.004951568645688312\n  (0, 19)\t0.0...
# 35   nicole_theriault    (0, 1)\t0.014444364866218556\n  (0, 2)\t0.00...
# 36          nut_meria    (0, 748)\t0.0018445058022700906\n  (0, 2236)...
# 37     pai_pongsatorn    (0, 369)\t0.0015181853097302911\n  (0, 2209)...
# 38            palapol    (0, 2309)\t0.001582280826657922\n  (0, 2356)...
# 39              palmy    (0, 394)\t0.0004055594203285885\n  (0, 408)\...
# 40   panadda_ruangwut    (0, 1)\t0.0007312485377850485\n  (0, 42)\t0....
# 42            paradox    (0, 111)\t0.0039945197444035165\n  (0, 139)\...
# 43     parn_thanaporn    (0, 2210)\t0.0021124069859976683\n  (0, 2225...
# 45      petch_saharat    (0, 555)\t0.0029302169683128746\n  (0, 2197)...
# 48         pu_pongsit    (0, 2199)\t0.003270539690451149\n  (0, 2200)...
# 51             scrubb    (0, 644)\t0.0018653255703097774\n  (0, 725)\...
# 52           sek_loso    (0, 263)\t0.006991766108160981\n  (0, 646)\t...
# 53        silly_fools    (0, 1)\t0.002966507130007668\n  (0, 2)\t0.00...
# 55       slot_machine    (0, 1)\t0.03275354492320442\n  (0, 3)\t0.009...
# 57  takkatan_chollada    (0, 2197)\t0.0018054372636871177\n  (0, 2209...
# 61            urboytj    (0, 1)\t0.02083662414726271\n  (0, 16)\t0.00...
# 62                vkl    (0, 0)\t0.0010375421878437827\n  (0, 1)\t0.0...
# 63      wan_thanakrit    (0, 316)\t0.006737410200442095\n  (0, 646)\t...
#
#     n_songs
# 0        35
# 1        35
# 2        35
# 6        35
# 7        35
# 8        35
# 9        35
# 10       35
# 11       35
# 12       35
# 13       35
# 16       35
# 23       35
# 24       35
# 25       35
# 28       35
# 31       35
# 33       35
# 34       35
# 35       35
# 36       35
# 37       35
# 38       35
# 39       35
# 40       35
# 42       35
# 43       35
# 45       35
# 48       35
# 51       35
# 52       35
# 53       35
# 55       35
# 57       35
# 61       35
# 62       35
# 63       35

# %%
song_filter_df.sample(5)
# Out:
#             artist            song_name                    href  \
# 667   keng_tachaya         ของรักของหวง   /music/thailyric/9621
# 1291  maew_jirasak              คำเดียว    /music/thailyric/767
# 1682      25_hours  เที่ยงคืนสิบห้านาที  /music/thailyric/11791
# 2165     nut_meria        ฉันอยู่ตรงไหน   /music/thailyric/2313
# 2060       mc_king            ส่วนหนึ่ง  /music/thailyric/18372
#
#                                                   lyric  lines  \
# 667   ขึ้นทรงคอคชาเอราวัณ ทหารแห่ โห่สนั่น หวั่นไหว\...      0
# 1291  ปากคนอย่างฉัน กับคำหวานๆ\rมันไม่ค่อยเข้ากัน เท...      0
# 1682  เที่ยงคืนสิบห้านาที กับวันที่ฉันนั่งเหม่อ\rที่...      0
# 2165  มองตาของเธอ ก็เจอเงาเขาอยู่ ไม่เคยจะรู้มีฉันอย...      0
# 2060  อย่าลืมเผื่อใจ ถ้าหากว่าเจาไปรักใคร จะได้ไม่ช้...      0
#
#                                                   words  n_words  \
# 667   [ขึ้น, ทรง, คอ, ค, ชา, เอราวัณ, ทหาร, แห่, โห่...      318
# 1291  [ปาก, คน, อย่าง, ฉัน, กับ, คำหวาน, ๆ\r, มัน, ไ...      261
# 1682  [เที่ยงคืน, สิบห้า, นาที, กับ, วันที่, ฉัน, นั...      257
# 2165  [มอง, ตา, ของ, เธอ, ก็, เจอ, เงา, เขา, อยู่, ไ...      216
# 2060  [อย่า, ลืม, เผื่อ, ใจ, ถ้าหากว่า, เจา, ไป, รัก...      392
#
#                                               words_str         artists  \
# 667   ขึ้น ทรง คอ ค ชา เอราวัณ ทหาร แห่ โห่ สนั่น หว...  {keng_tachaya}
# 1291  ปาก คน อย่าง ฉัน กับ คำหวาน ๆ\r มัน ไม่ค่อย เข...  {maew_jirasak}
# 1682  เที่ยงคืน สิบห้า นาที กับ วันที่ ฉัน นั่ง เหม่...      {25_hours}
# 2165  มอง ตา ของ เธอ ก็ เจอ เงา เขา อยู่ ไม่ เคย จะ ...     {nut_meria}
# 2060  อย่า ลืม เผื่อ ใจ ถ้าหากว่า เจา ไป รัก ใคร จะ ...       {mc_king}
#
#       duplicates  n_artists  unique_words_ratio  words_per_line  \
# 667            0          1            0.371069             inf
# 1291           0          1            0.241379             inf
# 1682           0          1            0.221790             inf
# 2165           0          1            0.333333             inf
# 2060           0          1            0.336735             inf
#
#                                           tf_idf_vector  tf_idf_score
# 667     (0, 13488)\t0.03915555302539431\n  (0, 13394...      7.256928
# 1291    (0, 13488)\t0.05812655795423931\n  (0, 13483...      5.986025
# 1682    (0, 13460)\t0.22392129673882685\n  (0, 13441...      4.911217
# 2165    (0, 13468)\t0.03960420886206716\n  (0, 13460...      6.540305
# 2060    (0, 13441)\t0.10462484899008165\n  (0, 13438...      8.878277

# %%
artist_song_filter_df = pd.merge(artist_filter_df[['artist', 'tf_idf_vector', 'n_songs']].assign(key = 0), 
                                 song_filter_df[['artist', 'tf_idf_vector', 'song_name']].assign(key = 0), on='key', 
                                 suffixes=['_artist', '_song']).drop('key', axis=1).reset_index(drop=True)
artist_song_filter_df['same_artist'] = artist_song_filter_df['artist_artist'] == artist_song_filter_df['artist_song']

# %%
artist_song_filter_df[artist_song_filter_df['same_artist']==False].head()
# Out:
#   artist_artist                               tf_idf_vector_artist  n_songs  \
# 0      25_hours    (0, 59)\t0.004297334094741244\n  (0, 662)\t0...       35
# 1      25_hours    (0, 59)\t0.004297334094741244\n  (0, 662)\t0...       35
# 2      25_hours    (0, 59)\t0.004297334094741244\n  (0, 662)\t0...       35
# 3      25_hours    (0, 59)\t0.004297334094741244\n  (0, 662)\t0...       35
# 4      25_hours    (0, 59)\t0.004297334094741244\n  (0, 662)\t0...       35
#
#       artist_song                                 tf_idf_vector_song  \
# 0  bird_thongchai    (0, 13468)\t0.024545557335906996\n  (0, 1346...
# 1  bird_thongchai    (0, 13455)\t0.07318947591287757\n  (0, 13399...
# 2  bird_thongchai    (0, 13460)\t0.08907922620038226\n  (0, 13455...
# 3  bird_thongchai    (0, 13460)\t0.09079480652329217\n  (0, 13455...
# 4  bird_thongchai    (0, 13455)\t0.03317924596013951\n  (0, 13370...
#
#      song_name  same_artist
# 0         Okay        False
# 1  กว่าจักรวาล        False
# 2        กำแพง        False
# 3  ชีวิตเดี่ยว        False
# 4    ผู้ต้องหา        False

# %%
# calculate similarity of artist tf idf vector and song vector
def tf_idf_vector_similarity(artist_vector, song_vector, songs, same_artist):
    # check if song is from same artist
    if same_artist:
        # deduct song vector from artist vector
        artist_vector = (songs * artist_vector - song_vector) / (songs - 1)
    # calculate similarity
    return cosine_similarity(artist_vector, song_vector)[0][0]

# %%
artist_song_filter_df['vector_similarity'] = artist_song_filter_df.apply(lambda row: tf_idf_vector_similarity(row['tf_idf_vector_artist'], 
                                                                     row['tf_idf_vector_song'], 
                                                                     row['n_songs'], row['same_artist']), axis=1)

# This function may take longer than 8 minutes.

# %%
df = artist_song_filter_df

fig = go.Figure()

fig.add_trace(go.Violin(x=df['artist_artist'][df['same_artist']],
                        y=df['vector_similarity'][df['same_artist']],
                        legendgroup='Same Artist', scalegroup='Same Artist', name='Same Artist',
                        side='negative')
             )
fig.add_trace(go.Violin(x=df['artist_artist'][~df['same_artist']],
                        y=df['vector_similarity'][~df['same_artist']],
                        legendgroup='Different Artists', scalegroup='Different Artists', name='Different Artists',
                        side='positive')
             )


fig.update_layout(
    width=2000,
    height=800,)
fig.update_traces(meanline_visible=True)
fig.update_layout(violingap=0, violinmode='overlay')
fig.update_layout(title='Similarity of Songs')
fig.update_xaxes(range=[-0.5, 9.5])
fig.update_yaxes(range=[-0.1, 0.8], title='Similarity')
fig.show()

# Note that you should click *Autoscale* on the figure option to show all artists' violins

# %% [markdown]
# ## Sentiment analysis

# %%
# polarity_lst = [-1] * len(song_df)
# subjectivity_lst = [-1] * len(song_df)

# for i, text in enumerate(song_df['lyric']):
#     sentiment = TextBlob(text)
#     polarity_lst[i] = sentiment.polarity
#     subjectivity_lst[i] = sentiment.subjectivity
    
# song_df['polarity'] = polarity_lst
# song_df['subjectivity'] = subjectivity_lst

# song_filter_df = song_filter_df.join(song_df[['polarity', 'subjectivity']])

# %% [markdown]
# ### Polarity and Subjectivity of Songs

# %%
# fig = px.scatter(song_filter_df, x='polarity', y='subjectivity', color='artist', hover_data=['song_name'], title='Polarity and Subjectivity of Songs')
# fig.show()

# %% [markdown]
# ### Polarity by artist

# %%
# fig = px.box(song_filter_df, x='artist', y='polarity', title='Polarity by artist')
# fig.show()

# %%
# song_filter_df

# %% [markdown]
# ## Export the feature-extracted data

# %%
with open('../../data_lyrics/thaisongs/fx_th_songs.bin',"wb") as f:
    pickle.dump(song_df, f)
